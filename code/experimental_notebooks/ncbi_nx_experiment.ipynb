# %%
import metagenompy
import numpy as np
from collections.abc import Iterable
import json

# %%
total_ncbi_networkx = metagenompy.generate_taxonomy_network(auto_download=False)
# Out:
# Parsing names: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3442683/3442683 [00:03<00:00, 899096.74it/s]
# Parsing nodes: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 2344973/2344973 [00:14<00:00, 161949.70it/s]

# %%
def reveal_all_attributes_of_nx(temp_nx):
    '''
    shows all keys that are present at least once as "attributes" of a networkx
    '''
    attribute_set=set()
    for temp_node in temp_nx.nodes:
        #attribute_list.add(set(temp_nx.nodes[temp_node].keys()))
        #print(set(temp_nx.nodes[temp_node].keys()))
        attribute_set=attribute_set.union(temp_nx.nodes[temp_node].keys())
        #hold=input('hold')
    return attribute_set

# %%
a={1,2}
b={2,3}
a.union(b)
a
# Out:
# {1, 2}

# %%
all_attribute_set=reveal_all_attributes_of_nx(total_ncbi_networkx)

# %%
all_attribute_set
# Out:
# {'acronym',
#  'authority',
#  'blast_name',
#  'common_name',
#  'equivalent_name',
#  'genbank_acronym',
#  'genbank_common_name',
#  'genbank_synonym',
#  'in-part',
#  'includes',
#  'rank',
#  'scientific_name',
#  'synonym',
#  'type_material'}

# %%
set_that_encapulates_node_id={
    'common_name',
    'genbank_common_name',
    'scientific_name'
}

# %%
len(total_ncbi_networkx.nodes)
# Out:
# 2344973

# %%
def flatten(xs):
    '''
    given a list of elements (can contain arbitrarily nested lists)
    creates a generator? of flattned elements
    warning: strings will become lists of char
    '''
    for x in xs:
        if isinstance(x, Iterable) and not isinstance(x, (str, bytes)):
            yield from flatten(x)
        else:
            yield x

# %%
a=[1,2,3,[4]]
a='hello'
a=['hellow',[1,23,4]]

list(flatten(a))
# Out:
# ['hellow', 1, 23, 4]

# %%
#see what the elements of each attribute look like
all_values_of_each_attribute={
    element:list() for element in all_attribute_set
}

for temp_node in total_ncbi_networkx.nodes:
    #print(temp_node)
    #print(total_ncbi_networkx.nodes[temp_node])
    for temp_attribute in total_ncbi_networkx.nodes[temp_node].keys():
        #print(np.asarray(total_ncbi_networkx.nodes[temp_node][temp_attribute]).flatten())
        #hold=input('hold')
        all_values_of_each_attribute[temp_attribute].append(
            total_ncbi_networkx.nodes[temp_node][temp_attribute]
        )
    #np.flatten(total_ncbi_networkx.nodes[a]

# %%
for element in all_values_of_each_attribute.keys():
    print(len(all_values_of_each_attribute[element]))
    print(element)
    print('-'*100)
# Out:
# 10554
# common_name
# ----------------------------------------------------------------------------------------------------
# 1150
# acronym
# ----------------------------------------------------------------------------------------------------
# 29957
# genbank_common_name
# ----------------------------------------------------------------------------------------------------
# 491203
# authority
# ----------------------------------------------------------------------------------------------------
# 485
# genbank_acronym
# ----------------------------------------------------------------------------------------------------
# 228
# blast_name
# ----------------------------------------------------------------------------------------------------
# 56148
# type_material
# ----------------------------------------------------------------------------------------------------
# 2344973
# scientific_name
# ----------------------------------------------------------------------------------------------------
# 447
# in-part
# ----------------------------------------------------------------------------------------------------
# 1096
# genbank_synonym
# ----------------------------------------------------------------------------------------------------
# 2344973
# rank
# ----------------------------------------------------------------------------------------------------
# 39588
# equivalent_name
# ----------------------------------------------------------------------------------------------------
# 43138
# includes
# ----------------------------------------------------------------------------------------------------
# 149521
# synonym
# ----------------------------------------------------------------------------------------------------

# %%
# for element in all_values_of_each_attribute.keys():
#     print(element)
#     hold=input('hold')
#     print(all_values_of_each_attribute[element][0:1000])
#     hold=input('hold')
    
    #print('-'*100)
    #hold=input('hold')

# %%
print(total_ncbi_networkx.nodes['2'])
# Out:
# {'rank': 'superkingdom', 'scientific_name': 'Bacteria', 'blast_name': 'bacteria', 'genbank_common_name': 'eubacteria', 'in-part': ['Monera', 'Procaryotae', 'Prokaryotae', 'Prokaryota', 'prokaryote', 'prokaryotes']}

# %%
list(flatten(total_ncbi_networkx.nodes['2']))
# Out:
# ['rank', 'scientific_name', 'blast_name', 'genbank_common_name', 'in-part']

# %%
all_values_of_each_attribute
# Out:
# {'common_name': [['Scheibenbakterien', 'Scheibenbakterien Muller 1911'],
#   'iron bacteria',
#   'Lyme Disease Borrelia',
#   'E. coli',
#   'rickettsialpox',
#   'agent of human granulocytic ehrlichiosis',
#   'equine monocytic ehrlichiosis agent',
#   ['Bacteroides-Cytophaga-Flexibacter group',
#    'BCF group',
#    'CFB group',
#    'Cytophaga-Flexibacter-Bacteroides phylum'],
#   'purple sulfur bacteria',
#   'photosynthetic flexibacteria',
#   ['blue-green bacteria', 'cyanophytes'],
#   'prochlorophytes',
#   ['purple bacteria and relatives',
#    'purple bacteria',
#    'purple non-sulfur bacteria',
#    'purple photosynthetic bacteria and relatives',
#    'purple photosynthetic bacteria'],
#   ['low GC Gram+', 'low G+C Gram-positive bacteria'],
#   ['anthrax bacterium', 'anthrax'],
#   'Melanogaster sex ratio organism',
#   'lemon',
#   'Ichang papeda',
#   ['apfelsine', 'naranja', 'navel orange', 'Valencia orange'],
#   'eukaryotes',
#   'rhodophytes',
#   ['carageen', 'carrageen', 'Irish moss'],
#   ['chrysomonads', 'chrysophytes'],
#   'coccolithophorids',
#   'bacillariophytes',
#   'dinophytes',
#   ['badderlocks', 'henware', 'murlin'],
#   'euglenophytes',
#   'green plants',
#   'sea lettuces',
#   "dead man's fingers",
#   ['charophytes', 'stoneworts'],
#   ['higher plants', 'land plants', 'plants'],
#   ['hepatics', 'liverwort'],
#   'hair mosses',
#   'whisk-fern family',
#   'whisk ferns',
#   'club mosses',
#   'spike mosses',
#   'clubmoss family',
#   'scouring rushes',
#   'common horsetail',
#   'Dutch rush',
#   'urajiro',
#   ['common sword fern', 'giant holly fern'],
#   'royal fern',
#   ['comptie', 'Florida arrowroot', 'guayiga'],
#   'ginkgo',
#   'cypress family',
#   ['giant arborvitae', 'Pacific red-cedar', 'western red-cedar'],
#   'pine family',
#   ['California red fir', 'red fir'],
#   'American larch',
#   'blue spruce',
#   'red spruce',
#   'black spruce',
#   ['haploxylon pines', 'soft pines'],
#   ['diploxylon pines', 'hard pines'],
#   ['Bhutan pine', 'blue pine', 'Himalayan white pine'],
#   'western bristlecone pine',
#   ['parasol pine', 'pignolia-nut pine'],
#   'Scotch pine',
#   'green pine',
#   ['big-cone pine', 'Coulter pine'],
#   'jack pine',
#   'golden larch',
#   ['fern-pine', "Henkel's podo", "Henkel's yellowwood"],
#   ['joint firs', 'ma huang', 'Mormon-tea'],
#   'sea-grape',
#   'angiosperms',
#   'seed plants',
#   'magnolia family',
#   'purple magnolia',
#   'southern magnolia',
#   ['Chinese magnolia', 'saucer magnolia'],
#   'bigleaf magnolia',
#   'sweetbay',
#   'broad leaved pepperbush',
#   'wild cinnamon family',
#   ['barbasco', 'curbana', 'wild cinnamon'],
#   ['Carolina-allspice', 'eastern sweetshrub'],
#   ['California-allspice', 'western sweetshrub'],
#   'laurel family',
#   'red bay',
#   'California bay tree',
#   'buttercup family',
#   'jack-in-the-green',
#   'cmmon buttercup',
#   'moonseed family',
#   'poppy family',
#   'rock harlequin',
#   'elm family',
#   ['hemp family', 'hop family'],
#   'kana-mugura',
#   'common hop',
#   'mulberry family',
#   ['campedak', 'cempedak', 'chempedak'],
#   'fig trees',
#   'mulberry trees',
#   'nettle family',
#   'stinging nettle',
#   'beech family',
#   'birches',
#   'birch family',
#   'white birch',
#   'canoe birch',
#   'black birch',
#   'bayberry family',
#   ['candleberry', 'southern bayberry', 'wax-myrtle'],
#   'red oak',
#   'alders',
#   'gray alder',
#   'pokeweed family',
#   ['common pokeberry',
#    'common pokeweed',
#    'red stem pokeweed',
#    'Virginia poke'],
#   ['food pokeberry', 'Indian pokeweed', 'shang lu'],
#   "four o'clock family",
#   'iceplant family',
#   'spear oracle',
#   ['field beet',
#    'garden beet',
#    'spinach chard',
#    'sugar beet',
#    'Swiss chard',
#    'table beet'],
#   'beet',
#   ["lamb's-quarters", 'pigweed', 'white goosefoot'],
#   'pigweed',
#   ['amaranth family', 'goosefoot family'],
#   ['green amaranth', 'pigweed', 'slim amaranth'],
#   ['Inca-wheat', 'jataco', 'love-lies-bleeding'],
#   'pink family',
#   'carnation',
#   'purslane family',
#   'Ceylon-spinach',
#   'carpet-weed family',
#   'green carpetweed',
#   'cactus family',
#   ['claw cactus', 'crab cactus', 'Thanksgiving cactus'],
#   ['putia', 'snake-eyes'],
#   'grape family',
#   ['Virginia-creeper', 'woodbine'],
#   'buckthorn family',
#   'common buckthorn',
#   'buckwheat family',
#   'rhubarb',
#   'Chinese gooseberry family',
#   ['Chinese gooseberry', 'kiwifruit'],
#   'mallow family',
#   ['butterprint', 'Indian mallow', 'velvetleaf'],
#   'Egyptian cotton',
#   ['American cotton', 'American upland cotton'],
#   ['chocolate', 'cocoa'],
#   'Brazil nut family',
#   'papaya family',
#   'mamon',
#   'cucumber family',
#   'wild melon',
#   'Oriental melon',
#   'snake cucumber',
#   ['netted muskmelon', 'nutmeg melon', 'Persian melo'],
#   'cucumbers',
#   ['pumpkins', 'squashes'],
#   ['Boston marrow', 'great pumpkin'],
#   ['ayote',
#    'Canada pumpkin',
#    'crookneck winter squash',
#    'cushaw squash',
#    'lacayote'],
#   'field pumpkin',
#   ['bottle gourd', 'calabash'],
#   ['dishcloth gourd', 'loofa', 'sponge gourd', 'vegetable sponge'],
#   ['balsam pear', 'bitter gourd'],
#   ['gua lou', 'Mongolian snake-gourd', 'tian hua fen'],
#   'begonia family',
#   'passionflower famly',
#   'giant granadilla',
#   'willow family',
#   ['poplar', 'poplar trees'],
#   ['Canadian poplar', 'Carolina poplar'],
#   ['black poplar', 'Lombardy poplar'],
#   'western balsam poplar',
#   ['mouse-ear cress', 'thale-cress'],
#   'horseradish',
#   ['brown mustard', 'Indian mustard'],
#   ['oilseed rape', 'rapeseeds'],
#   ['rutabaga', 'Swedish turnip'],
#   ['collards', 'fodder kale'],
#   'Chinese broccoli',
#   'cauliflower',
#   ['Abyssinian crambe', 'Abyssinian kale'],
#   ['bai jie', 'yellow mustard'],
#   'horseradish tree family',
#   'maranga',
#   'sapodilla family',
#   ['chicle', 'sapodilla', 'sapote'],
#   ['miracle fruit', 'sweet berry'],
#   'rose family',
#   ['apple tree', 'cultivated apple'],
#   'European crab apple',
#   'sweet almond',
#   ['Cheju native flowering cherry', 'Potomac cherry', 'Yoshino cherry'],
#   'damask rose',
#   'sha li',
#   'stonecrop family',
#   'saxifrage family',
#   'alumroot',
#   'bittersweet family',
#   'currant family',
#   ['eastern black currant', 'wild black currant'],
#   'pea family',
#   ['Barbados pride',
#    'Circassian bean',
#    'Condori wood',
#    'red sandalwood tree',
#    'sandal bead tree'],
#   ["crab's eye", "crab's-eye", 'rosary pea'],
#   ['goober', 'ground-nut'],
#   'horse bean',
#   'Japanese jack bean',
#   'garbanzo',
#   'cluster bean',
#   ['catjang', 'catjang cowpea', 'sow-pea'],
#   'lucky beantree',
#   'coral tree',
#   ['ci tong', 'dabdab', 'Indian coral tree'],
#   'soybeans',
#   'wild soybean',
#   'yellow pea',
#   'red pea',
#   'hairy vetchling',
#   ['chickling vetch', 'white pea'],
#   ['cassie', 'granadillo bobo', 'ipil ipil', 'jumbie bean', 'jump-and-go'],
#   'perennial horse gram',
#   ['sickle alfalfa', 'yellow-flower alfalfa', 'yellow lucerne'],
#   ['alfalfa', 'lucerne'],
#   ['French bean', 'kidney bean', 'string bean'],
#   'scarlet runner bean',
#   ['garden pea', 'peas'],
#   ['asparagus bean', 'asparagus pea', 'Goa bean', 'winged beans'],
#   'kudzu',
#   'creeping white clover',
#   'gorse',
#   ['broad bean', 'faba bean'],
#   'tick bean',
#   ['spring vetch', 'tare'],
#   ['black-pod vetch', 'common vetch', 'narrow-leaf vetch'],
#   'azuki bean',
#   ['urad dal', 'urd-bean'],
#   ['golden gram', 'green gram'],
#   'mung bean',
#   'moth-bean',
#   ['black-eyed pea', 'crowder pea'],
#   'Japanese wistaria',
#   'apple-leaf',
#   'loosestrife family',
#   'myrtle family',
#   'evening-primrose family',
#   'gusight clarkia',
#   "Bertero's evening primrose",
#   'pink-ladies',
#   'Indian almond family',
#   ['Rangoon-creeper', 'shi jun zi'],
#   'sandlewood family',
#   ['buffalo nut', 'rabbitwood'],
#   'catkin mistletoe family',
#   'spurge family',
#   ['jebe', 'Para rubber tree', 'siringa'],
#   ['manioc', 'tapioca', 'yuca'],
#   ['annual mercury', 'herb mercury'],
#   "wolf's milk",
#   ['goatnut', 'jojoba'],
#   'boxwood family',
#   'flax family',
#   'sumac family',
#   ['Chinese lacquer',
#    'Japanese lacquer tree',
#    'Japanese lacquer-tree',
#    'varnish tree'],
#   'frankincense family',
#   'nasturtium family',
#   'geranium family',
#   ['bedding geranium',
#    'house geranium',
#    'zonal geranium',
#    'zonal pelargonium'],
#   'wood-sorrel family',
#   'carrot family',
#   ['carrots', "Queen Anne's lace"],
#   'cilantro',
#   'navelworts',
#   'ginseng family',
#   'English ivy',
#   ['Asiatic ginseng',
#    'Chinese ginseng',
#    'ginseng',
#    'hong shen',
#    'insam',
#    'jinso',
#    'Korean ginseng',
#    'ninjin',
#    'ren seng',
#    'sansam'],
#   'dogbane family',
#   ['chatas', 'chula', 'old-maid', 'rosy periwinkle'],
#   'devilpepper',
#   ['bowstring hemp', 'madar'],
#   'nightshade family',
#   ['bird pepper', 'chili pepper', 'hot pepper'],
#   'downy thornapple',
#   'common thornapple',
#   ['black henbane',
#    'chupa mieles',
#    "hog's-bean",
#    'stinking-nightshade',
#    'tian xian zi'],
#   'Peruvian tomato',
#   'currant tomato',
#   ['flowering tobacco',
#    'Indian tobacco',
#    'ornamental tobacco',
#    'winged tobacco'],
#   'glaucous tobacco',
#   'leadwort-leaved tobacco',
#   'wild tobacco',
#   ['American tobacco', 'tobacco'],
#   'petunia',
#   'garden petunia',
#   'violet-flowered petunia',
#   ['aubergine', 'brinjal'],
#   'potatoes',
#   'morning-glory family',
#   'batate',
#   'giant dodder',
#   'waterleaf family',
#   'mint family',
#   ['Chinese motherwort', 'sagebrush motherwort', 'yi mu cao'],
#   ['spur flowers', 'Swedish ivies'],
#   'olive famly',
#   'olives',
#   'jessamines',
#   'figwort family',
#   'garden snapdragon',
#   ['common monkey flower', 'yellow monkey flower'],
#   'cutleaf monkeyflower',
#   'witchweeds',
#   'witchweed',
#   'brooklimes',
#   'sesame family',
#   ['beniseed', 'gingelly', 'hu ma', 'koba'],
#   'butterworts',
#   'blueflower butterwort',
#   'honeysuckle famly',
#   ['dockmackie', 'mapleleaf viburnum'],
#   ['moschatel', 'muskroot', 'townhall clock'],
#   'daisy family',
#   'ragweeds',
#   ['annual ragweed', 'short ragweed'],
#   ['common wormwood', 'mugwort'],
#   ['niger', 'ramtil', 'ramtilla', 'werinnua'],
#   'sunflowers',
#   'Jerusalem artichoke',
#   ['cultivated lettuce', 'garden lettuce'],
#   'tarweeds',
#   'common Madia',
#   ['cardoon', 'wild artichoke'],
#   'Barbados cherry family',
#   ['craboo', 'golden-spoon', 'indano', 'murici', 'nance', 'yoco'],
#   'drumheads',
#   'dogwood family',
#   ['bunchberry', 'creeping dogwood', 'dwarf cornel'],
#   'flowering dogwood',
#   'panicled dogwood',
#   'cornelian cherry',
#   'holly family',
#   ['box-leaf holly', 'Japanese holly'],
#   'yaupon',
#   'English holly',
#   "Perny's holly",
#   'mountain holly',
#   ['burningbush', 'winged euonymus'],
#   'winterberry euonymus',
#   'karaka',
#   'mustard-tree family',
#   'protea family',
#   'primrose family',
#   'heath family',
#   'pinedrops',
#   'pitcher plant family',
#   'California pitcherplant',
#   'pitcherplants',
#   'yellow pitcherplant',
#   'sundew family',
#   'sundews',
#   'dewthread',
#   'mao gao cai',
#   'bellflower family',
#   'witch-hazel family',
#   'American witch-hazel',
#   'American sweet gum',
#   'plane-tree family',
#   ['plane trees', 'sycamores'],
#   ['American sycamore', 'eastern plane-tree', 'eastern sycamore'],
#   'water-lily family',
#   'pond-lily',
#   'American white water-lily',
#   ['irupe', 'Santa Cruz water-lily'],
#   'water-shield family',
#   'hornwort',
#   'lotus family',
#   ['American lotus', 'yellow lotus'],
#   ['Indian lotus', 'padma'],
#   'leadwort family',
#   'tea family',
#   'black tea',
#   'common camellia',
#   'monocots',
#   'water-plantain family',
#   ['Old World arrowhead', 'swamp potato', 'swan potato'],
#   'arum family',
#   ['ape', 'cunjevoi', 'malanga'],
#   'cuckoo-pint',
#   ['cocoyam', 'dasheen', 'eddo', "elephant's ear", 'kalo', 'malanga'],
#   'sweet flag family',
#   ['flagroot', 'sweet flag'],
#   'shellflower',
#   'grass family',
#   ['cultivated oat', 'cultivated oats'],
#   ['cheat', 'chess bromegrass', 'chess', 'rye brome'],
#   'cocksfoot',
#   'barleys',
#   'barley',
#   'foxtail barley',
#   'perennial ryegrass',
#   ['long-staminate rice', 'red rice'],
#   ['common wild rice', 'red rice'],
#   'red rice',
#   'panicgrasses',
#   ['broom millet', 'common millet', 'proso millet'],
#   ['bulrush millet', 'cattail millet', 'pearl millet'],
#   ['noble cane', 'sugarcane'],
#   'cultivated sugarcanes',
#   ['broomcorn', 'milo'],
#   'Johnson grass',
#   ['Canadian hard winter wheat', 'common wheat', 'wheat'],
#   'common wheat x Sanduri wheat',
#   ['cone wheat', 'English wheat', 'poulard wheat', 'rivet wheat'],
#   ['einkorn wheat', 'one-grained wheat', 'small spelt'],
#   'Sanduri wheat',
#   ['chapule', 'milpilla', 'teosinte'],
#   'maize',
#   ['annual teosinte', 'Mexican teosinte', 'teosinte'],
#   ['perennial teosinte', 'teosinte'],
#   ['anjan', 'birdwood grass'],
#   'tall wheatgrass',
#   'crested wheatgrass',
#   'beardless wheatgrass',
#   'tall fescue',
#   'meadow ryegrass',
#   'sedge family',
#   'bromeliad family',
#   'prayer-plant family',
#   ['katemfe', 'miracle fruit'],
#   'canna family',
#   ['canna', 'edible canna', 'gruya', 'Indian-shot', 'Queensland arrowroot'],
#   'banana family',
#   ['banana', 'dessert bananas', 'sweet banana'],
#   'ginger family',
#   'bird-of-paradise family',
#   'white bird-of-paradise',
#   'amaryllis family',
#   'yam family',
#   'yama-no-imo',
#   'lumbah',
#   'lily family',
#   'wild garlic',
#   'Easter lily',
#   'autumn-crocus family',
#   'catbrier famly',
#   ['palm family', 'palms'],
#   'nypa palm',
#   'Senegal date palm',
#   'saw palmetto',
#   'screw-pine family',
#   ['hala', 'pandan', 'thatch screw-pine', "Veitch's screw pine"],
#   ['bur-reed family', 'cattail famly'],
#   'common cattail',
#   'spiderwort family',
#   'orchid family',
#   'thraustochytrids',
#   ['potato late blight', 'potato late blight fungus'],
#   ['potato pink rot agent', 'potato pink rot fungus'],
#   'buckeye rot agent',
#   'sac fungi',
#   ["brewer's yeast", 'S. cerevisiae'],
#   ['blackleg of canola fungus', 'blackleg of crucifers fungus'],
#   'kerosene fungus',
#   'Dutch elm disease fungus',
#   "witches' butter",
#   'smuts',
#   'shimeji',
#   ['button mushroom', 'common mushroom', 'cultivated mushroom'],
#   'violet root rot',
#   'maitake',
#   'chicken-of-the-woods',
#   'parabasalians',
#   'diplomonads',
#   'eustigmatophytes',
#   'brain-eating amoeba',
#   'colpodids',
#   'microsporidians',
#   'multicellular animals',
#   "Mueller's freshwater sponge",
#   'coelenterates',
#   'brown hydra',
#   'actinians',
#   'frilled sea anemone',
#   'staghorn coral',
#   'elkhorn coral',
#   'sea pansies',
#   ['box jellies', 'box jellyfishes'],
#   'flatworm',
#   'Southeast Asian liver fluke',
#   'pig tapeworm',
#   'rat tapeworm',
#   ['bootlace worms', 'nemertines'],
#   'milky ribbon worm',
#   ['nematode', 'nematodes', 'roundworm'],
#   'roundworm',
#   'feline roundworm',
#   'sealworm',
#   'agent of lymphatic filariasis',
#   'canine heartworm nematode',
#   'red stomach worm',
#   'agent of lymphatic filariasis',
#   ['pine wilt nematode', 'pinewood nematode'],
#   'rock worm',
#   ['brandling worm',
#    'common dung-worm',
#    'red wiggler worm',
#    'redworm',
#    'tiger worm'],
#   ['pogonophores', 'vestimentiferans'],
#   'giant tube worm',
#   ['fat innkeeper worms', 'innkeeper worms'],
#   ['peanut worm', 'sipunculids'],
#   'peanut worm',
#   'molluscs',
#   'abalone',
#   'California red abalone',
#   'horn shell',
#   'fish-hunting cone snail',
#   'bloodfluke planorb',
#   'edible snail',
#   ['blue mussel', 'edible mussel'],
#   'bay mussel',
#   'low-rib ark',
#   'ezo giant scallop',
#   'Atlantic surf-clam',
#   ['jackknife clam', 'razor shell'],
#   'sun-ray clam',
#   'northern quahog',
#   'softshell',
#   'cuttlefishes',
#   'sea monkeys',
#   'water flea',
#   'ostracodes',
#   'giant barnacle',
#   ['giant tiger prawn', 'tiger prawn'],
#   ['white Pacific shrimp', 'white shrimp'],
#   'lobsters',
#   'northern red shrimp',
#   'broad-fingered crayfish',
#   'narrow-fingered crayfish',
#   'Kamchatka crab',
#   'hermit crabs',
#   'true crabs',
#   'rock crab',
#   'common shore crab',
#   'mud crabs',
#   ['Indo-Pacific swamp crab', 'mud crab', 'Samoan crab'],
#   'amphipods',
#   'tidepool copepod',
#   'chelicerates',
#   'mangrove horseshoe crab',
#   'Chinese horseshoe crab',
#   ['Chinese horseshoe crab', 'Japanese horseshoe crab'],
#   'Mexican scorpion',
#   'bark scorpion',
#   'yellow scorpion',
#   'mygalomorphs',
#   ['baboon spiders', 'bird spiders'],
#   ['black widow spider', 'southern black widow'],
#   'black widow spider',
#   'soft ticks',
#   ['hard ticks', 'scale ticks'],
#   'cattle tick',
#   ['blacklegged tick', 'deer tick', 'shoulder tick'],
#   'skimmers',
#   ['ten-spot pond skimmer', 'twelve-spotted skimmer'],
#   'cinereous cockroach',
#   'house crickets',
#   ['lubber grasshopper', 'southeastern lubber grasshopper'],
#   ['spur-throated grasshoppers', 'spur-throated locusts'],
#   'desert locust',
#   'gray bird locust',
#   'true grasshoppers',
#   'stick insects',
#   ["Macleay's spectre", "Macleay's spectre stick insect"],
#   'sweet potato whitefly',
#   'firefly beetles',
#   'genji firefly',
#   'North American firefly',
#   'lamellicorn beetles',
#   ['flower beetles', 'goliath beetles'],
#   'chafers',
#   'maybug',
#   ['darkling beetles', 'long-jointed beetles'],
#   'rust-red flour beetle',
#   ['giant mealworm beetle',
#    'giant mealworm',
#    'kingworm beetle',
#    'kingworm',
#    'superworm'],
#   ['lady beetles', 'ladybirds', 'ladybugs'],
#   'moths',
#   ['silk moth', 'silkworm'],
#   'common lackey',
#   'noctuid moths',
#   ['pigweed caterpillar', 'small mottled willow caterpillar'],
#   'Egyptian cotton leafworm',
#   ['bollworm', 'tomato fruitworm'],
#   ['cabbage butterfly', 'large white', 'white butterfly'],
#   'giant silkworm moths',
#   ['Chinese oak silk moth', 'oak silkmoth'],
#   ['Japanese oak silk moth', 'oak silkmoth'],
#   'cynthia moth',
#   ['Carolina sphinx', 'hornblower', 'tobacco hawkmoth', 'tomato hornworm'],
#   'spruce budworm',
#   ['American swallowtail', 'eastern black swallowtail'],
#   'midge',
#   'forest day mosquito',
#   'common malaria mosquito',
#   'western malaria mosquito',
#   'dark-winged fungus gnats',
#   'blackflies',
#   'sand flies',
#   'moth flies',
#   ['deerflies', 'horseflies'],
#   'horse fly',
#   'fruit fly',
#   'medfly',
#   'fruit fly',
#   ['blow flies', 'blow flly', 'blowflly', 'blow-fly', 'bottle flies'],
#   'greenbottle fly',
#   ['bot flies', 'botflies'],
#   'common cattle grub',
#   'tsetse fly',
#   'tsetse fly',
#   'tsetse fly',
#   'tsetse fly',
#   'tsetse fly',
#   'tsetse fly',
#   'hymenopterans',
#   'solitary wasp',
#   'true wasps',
#   'white-face hornet',
#   'Japanese hornet',
#   'bee',
#   ['bee', 'European honey bee', 'honeybee', 'Western honey bee'],
#   ['Eastern honeybee', 'Indian honeybee', 'oriental honeybee'],
#   'rock honeybee',
#   'dwarf honeybee',
#   ['common honeybee', 'Italian honeybee'],
#   'rotton-wood termites',
#   'European mantid',
#   'lacewings',
#   'stinkflies',
#   'centipede',
#   'myriapods',
#   'millipede',
#   'brachiopods',
#   'deuterostomes',
#   ['sea stars', 'starfish'],
#   ['Northern Pacific seastar', 'North Pacific seastar'],
#   'ochre sea star',
#   'sea urchin',
#   'punctuate sea urchin',
#   'painted sea urchin',
#   'common sea urchin',
#   'angulate sea urchin',
#   'sand sea urchin',
#   'purple urchin',
#   'pale urchin',
#   'holothurians',
#   ['sea vase', 'yellow sea squirt'],
#   ['amphioxi', 'amphioxius'],
#   'California amphioxus',
#   'common lancelet',
#   ['fishes', 'fish'],
#   'southern hemisphere lamprey',
#   ['marine lamprey', 'sea lampreys'],
#   ['fishes', 'fish'],
#   'California hagfish',
#   ['common hagfish', 'hagfish'],
#   ['fishes', 'fish'],
#   'electric rays',
#   'torpedo rays',
#   'spotted torpedo',
#   'horn sharks',
#   ['smaller spotted dogfish', 'spotted catshark', 'spotted dogfish'],
#   'spinous shark',
#   'longfin mako',
#   ['sea fox',
#    'swiveltail',
#    'thintail thresher',
#    'thresher',
#    'whip-tail shark'],
#   'bluntnose sevengill shark',
#   'elephantfishes',
#   ['Australian ghost shark',
#    'elephant fish',
#    'ghost shark',
#    'makorepe',
#    'plownose chimaera',
#    'reperepe'],
#   'ratfishes',
#   'Pacific ratfish',
#   ['dipnoans', 'fishes', 'fish'],
#   'African lungfish',
#   'lobe-finned fishes',
#   ['fishes', 'fish', 'lobe-finned fishes'],
#   ['fishes', 'fish'],
#   ['Caspian sturgeon', 'osietra'],
#   ['sevruga', 'starry sturgeon'],
#   'short-nose sturgeon',
#   'North American paddlefish',
#   'ladyfishes',
#   'European freshwater eel',
#   'marbled eel',
#   'Australian eel',
#   'conger eel',
#   'pike eel',
#   'Sundaland noodlefishes',
#   ['leopard danio', 'zebra danio', 'zebra fish'],
#   ['carp', 'fancy carp', 'koi', 'mirror carp'],
#   ['noble carp', 'silver carp'],
#   'smallmouth buffalo fish',
#   'weatherfish',
#   'blind cave fish',
#   'North American freshwater catfishes',
#   'Pangas catfish',
#   'electric knifefish',
#   'electric knifefish',
#   'humpback salmon',
#   ['Japanese salmon', 'masu salmon', 'salmon trout'],
#   'amemasu char',
#   'tadpole cod',
#   'pollock',
#   'southern hakes',
#   ['Atlantic hake', 'chat', 'densack', 'seapike'],
#   ['American goosefish', 'anglerfish'],
#   'allmouth goosefish',
#   'pupfishes',
#   ['Atlantic killifish', 'killifish'],
#   'ricefishes',
#   ['Japanese rice fish', 'medaka'],
#   'Baikal oilfishes',
#   'grubby',
#   ['daddy sculpin',
#    'father lasher',
#    'scorpion fish',
#    'short spined sea scorpion'],
#   'lumpsuckers',
#   'lumpsucker',
#   'rockfishes',
#   'Rio Grande cichlid',
#   ['Hawaiian perch',
#    'Hawaiian sunfish',
#    'Java tilapia',
#    'largemouth tilapia',
#    'Mozambique cichlid'],
#   'dwarf Tanganyikan cichlid',
#   'pompanos',
#   'five-ray yellowtail',
#   ['Japanese seabass', 'suzuki'],
#   ['perch', 'redfin'],
#   ['common sea bream', 'red porgy'],
#   ['gilthead bream', 'silver seabream'],
#   ['Asian seabass', 'barramundi'],
#   'Canadian eel pout',
#   ['mother-of-eels', 'muttonfish', 'North-Atlantic ocean pout', 'poodler'],
#   'wolf-fish',
#   'cod icefishes',
#   'yellowbelly rockcod',
#   'Antarctic dragonfish',
#   ['burrowing gobies', 'wormfishes'],
#   'tunas',
#   'bonito',
#   ['island bonito', 'island skipjack', 'kawakawa'],
#   ['bluefin tuna', 'northern bluefin tuna'],
#   ['northern bluefin tuna', 'North Pacific bluefin tuna'],
#   'parrotfishes',
#   ['bastard halibut', 'false halibut', 'olive flounder'],
#   'plaice',
#   ['flashlight fishes', 'flashlight fish'],
#   'chub',
#   'peacock sole',
#   'big salamanders',
#   'Eastern tiger salamander',
#   'congo snakes',
#   ['Congo eel', 'Congo snake', 'two-toed Congo eel', 'two-toed salamander'],
#   'three-toed amphiuma',
#   'red-spotted newt',
#   ['Spanish newt', 'Spanish ribbed newt'],
#   ['rough-skinned newts', 'roughskin newts'],
#   ['rough-skin newt', 'roughskin newt'],
#   'great crested newt',
#   'smooth newt',
#   'southern crested newt',
#   ['Alpine crested newt', 'Alpine warty newt', 'Italian newt'],
#   'Japanese common newt',
#   ['mushroomtongue salamanders', 'tropical lungless salamanders'],
#   'slimy salamanders',
#   'red-cheeked salamander',
#   'dwarf siren',
#   ['anurans', 'frogs'],
#   'firebelly toads',
#   'Oriental fire-bellied toad',
#   'pipid frogs',
#   'Marasbit clawed frog',
#   ['clawed frog', 'common platanna', 'platanna'],
#   'western clawed frog',
#   'Australian frogs',
#   'Australian leptodactylic frog',
#   ['Australian leptodactylic frog',
#    'chubby gungan',
#    'mud toadlet',
#    'red-groined toadlet'],
#   'Australian frog',
#   'Neotropical frogs',
#   ['common European toad', 'European toad'],
#   ['cane toad', 'giant toad'],
#   'Rio Viejo toads',
#   'Japanese common toad',
#   'Southern Gulf Coast frog',
#   "Sauvage's leaf frog",
#   'true frogs',
#   ['bullfrog', 'bullfrogs'],
#   ['Iberian water frog', "Perez's frog", 'Western Mediterranian green frog'],
#   ['European green frog', 'laughing frog'],
#   'European common frog',
#   ['black-spotted frog', 'three-striped pond frog'],
#   'wrinkled frog',
#   'Riobamba pouched frog',
#   ['treefrogs', 'true tree toads'],
#   "Thomasset's frog",
#   'American bell toad',
#   ['common midwife toad', 'nurse frog', 'olive midwife toad'],
#   "Stejneger's caecilian",
#   'Frigate Island caecilian',
#   'Indian caecilians',
#   'Banna caecilian',
#   'anapsid reptiles',
#   ['loggerhead', 'red sea turtle'],
#   'green seaturtle',
#   "Kemp's ridley sea turtle",
#   'snapping turtle',
#   'pond turtles',
#   'terrapin',
#   'common caiman',
#   'African crocodile',
#   'estuarine crocodile',
#   'rhynchocephalians',
#   'hatteria',
#   'common iguana',
#   'western fence lizard',
#   'tegu',
#   'scincomorph lizards',
#   'cape monitor',
#   'common wall gecko',
#   'dice snake',
#   'common death adder',
#   'shield-nose snake',
#   'black-banded sea krait',
#   ['broad-banded blue sea snake', 'Erabu sea snake'],
#   'long-glanded coral snake',
#   ['Central American coral snake', 'gargantilla'],
#   'harlequin coralsnake',
#   'black-lipped cobra',
#   'black-necked spitting cobra',
#   'Taiwan cobra',
#   'Oxus cobra',
#   'common tiger snake',
#   'king brown snake',
#   'eastern brown snake',
#   'common sea snake',
#   'yellow-bellied sea snake',
#   'African puff adder',
#   'horned adder',
#   'Gaboon adder',
#   'rhinoceros adder',
#   'horned desert viper',
#   'Siberian pit viper',
#   ['island jararaca', 'Queimada jararaca'],
#   ['common lancehead', 'fer-de-lance'],
#   'cascabel',
#   ['cascabel', 'South American rattlesnake'],
#   ['green pit viper', 'white-lipped pit viper'],
#   'green habu snake',
#   'hime-habu',
#   ['Australian cassowary', 'double-wattled cassowary'],
#   'lesser rhea',
#   'common rhea',
#   'ostrich',
#   ['South Island tokoweka', 'tokoweka'],
#   'brown kiwi',
#   'cape widgeon',
#   ['European wigeon', 'widgeon'],
#   ['duck', 'mallard duck', 'mallard ducks'],
#   'northern mallard',
#   ['graylag goose', 'greylag goose'],
#   ['Chinese goose', 'white Chinese goose'],
#   ['muscovy', 'musky duck'],
#   'Magellan goose',
#   'West Indian tree duck',
#   'wandering whistling tree duck',
#   ['black-bellied tree duck', 'red-billed whistling-duck'],
#   'fulvous tree duck',
#   'plumed whistling duck',
#   'white-faced tree duck',
#   'lake duck',
#   'burdekin shelduck',
#   ['Eurasian swift', 'Mauersegler', 'swift'],
#   'spur-winged lapwing',
#   'great black-backed gull',
#   'lesser black-backed gull',
#   ['carrier pigeon', 'domestic pigeon', 'rock dove'],
#   'common koel',
#   ['greater roadrunner', 'roadrunner'],
#   ['peregrine', 'Wanderfalke'],
#   ['Eurasian goshawk', 'goshawk', 'Habicht'],
#   'marsh harrier',
#   'African harrier-hawk',
#   'scrubfowl',
#   'mallee fowl',
#   ['greater sage grouse', 'sage grouse'],
#   ['American quails', 'New World quails'],
#   'chesnut bellied scaled quail',
#   ['bobwhite quail', 'common bobwhite'],
#   "Mearns's quail",
#   ['gray partridge', 'Indian grey partridge'],
#   'bare-throated francolin',
#   ['bantam', 'chickens'],
#   'Grey junglefowl',
#   ['Himalayan monal', 'Himalayan monal pheasant', 'Impeyan monal'],
#   "Edward's pheasant",
#   'blue peafowl',
#   ['gray partridge', 'Rebhuhn'],
#   'common pheasant',
#   'peacock-pheasant',
#   'koklass pheasant',
#   'copper pheasants',
#   'satyr tragopan',
#   "Temminck's tragopan",
#   ['common turkey', 'wild turkey'],
#   'common hill-partridge',
#   'coot',
#   'common coot',
#   'canaries',
#   ['Atlantic canary', 'canary'],
#   'birds of paradise',
#   'buff-tailed sicklebill',
#   'Kohlmeise',
#   'tree sparrow',
#   ['European starling', 'starling'],
#   ['Amsel', 'Eurasian blackbird'],
#   'robin',
#   'red-naped bushshrike',
#   ['common cormorant', 'cormorant'],
#   ['black cormorant', 'black shag'],
#   'darters',
#   'greater flamingo',
#   'parrot',
#   'blue and gold macaw',
#   'Ring-necked Parakeet',
#   'small buttonquail',
#   ['duck-billed platypus', 'duckbill platypus'],
#   'short-beaked echidna',
#   'American opossums',
#   'Virginia opossum',
#   ['Tasmanian tiger', 'thylacine'],
#   ['marsupial cats', 'native cats', 'tiger cats'],
#   'eastern quoll',
#   'brush-tailed marsupial mice',
#   'Australian stripe-faced dunnart',
#   'Rat-kangaroos',
#   ['long-nosed rat kangaroo', 'potoroo'],
#   ["Bennett's wallabies", "Bennett's wallaby"],
#   'antilopine wallaroo',
#   'hill wallaroo',
#   'yellow-footed rock wallaby',
#   'Queensland ringtail',
#   ['common brush-tailed possum', 'silver-gray brushtail possum'],
#   ['eutherian mammals', 'placental mammals'],
#   'northern tamandua',
#   'three-toed sloth',
#   'pale-throated three-toed sloth',
#   ['brown-throated three-fingered sloth', 'brown-throated three-toed sloth'],
#   "Hoffmann's two-toed sloth",
#   'armadillo',
#   ['common hedgehog', 'European hedgehog'],
#   'gymnures',
#   'four-toed hedgehog',
#   'lesser hedgehog tenrec',
#   'Asian house shrew',
#   'northern short-tailed shrew',
#   'tree shrew',
#   'Old World fruit bats',
#   'greater short-nosed fruit bat',
#   'grey-headed flying fox',
#   'variable flying fox',
#   ['Australian false vampire bat', 'Australian giant false vampire'],
#   'greater false vampire bat',
#   'American leaf-nosed and vampire bats',
#   'California leaf-nosed bat',
#   'greater round-eared bat',
#   'vampire bat',
#   'vespertilionid bats',
#   ['Common bent-wing bat', "Schreibers's long-fingered bat"],
#   'cave myotis',
#   'weasel sportive lemur',
#   'variegated lemur',
#   'colugos',
#   'fat-tailed dwarf lemur',
#   'bushbabies',
#   ['greater galago', 'thick-tailed galago'],
#   'northern lesser bushbaby',
#   'tarsier',
#   'Western tarsier',
#   ['monkey', 'monkeys'],
#   ['common marmoset', 'white ear-tufted marmoset'],
#   ['saddle-backed tamarin', 'saddlebacked tamarin'],
#   'black-chested mustached tamarin',
#   'black-mantled tamarin',
#   'emperor tamarin',
#   "Goeldi's monkey",
#   'red howler monkey',
#   ['night monkey', 'northern night monkey', 'owl monkey'],
#   'long-haired spider monkey',
#   'Central American spider monkey',
#   ['brown pale-fronted capuchin', 'pale-fronted capuchin'],
#   ['black-capped capuchin', 'brown-capped capuchin', 'brown capuchin'],
#   ['white-faced capuchin', 'white-throated capuchin'],
#   ['common woolly monkey', "Humboldt's woolly monkey"],
#   'South American squirrel monkey',
#   'Dusky titi',
#   'brown-bearded saki',
#   ['monkey', 'monkeys'],
#   ['red-capped mangabey', 'red-crowned mangabey', 'white-collared mangabey'],
#   ['African green monkey', 'African green monkeys', 'savanah monkey'],
#   'moustached monkey',
#   ['hussar', 'patas monkey'],
#   ...],
#  'acronym': ['BEV',
#   'MAC',
#   'CPXV',
#   'FWPV',
#   'SPPV',
#   'SFV',
#   'SPV',
#   'MOCV',
#   'McVI',
#   'McVII',
#   'CbEPV',
#   'HaEPV',
#   ['HSV-1', 'HSV1'],
#   'HSV2',
#   'SA8',
#   'EHV-1',
#   ['EHV-4', 'EHV4'],
#   'VZV',
#   ['GaHV-1', 'ILTV'],
#   'PRV',
#   'BHV-4',
#   'HHV6',
#   ['EHV-5', 'EHV5'],
#   ['EPV', 'HHV-4'],
#   'MDV1',
#   'OvHV2',
#   'GSHV',
#   'HBV',
#   'HDV',
#   'DHBV',
#   'LdMNPV',
#   'PfMNPV',
#   'SeMNPV',
#   'SfNPV',
#   'SlNPV',
#   'TnGV',
#   'GV',
#   'PbGV',
#   ['HzNPV', 'HzSNPV'],
#   'TTV1',
#   'CsPDV',
#   'TIV',
#   'FV3',
#   'ASFV',
#   'PBCV-1',
#   ['BAd3', 'bos3'],
#   'HAdV-C',
#   'HAdV-F',
#   'HAdV-D',
#   'HAdV-A',
#   'MAV-1',
#   'CELO',
#   'BPV-3',
#   'BPV-4',
#   'BPV-6',
#   'EEPV',
#   'RPV',
#   'RHPV 1',
#   ['HPV 11', 'HPV-11'],
#   'CRPV',
#   'BKV',
#   'CERV',
#   'CAMV',
#   'FMV',
#   'RTBV',
#   'Bacillus phage SP01',
#   'ADV',
#   'AMDV',
#   'BPV',
#   'FPLV',
#   'CPV',
#   'MEV',
#   'MMV',
#   'PPV',
#   'AAV2',
#   'CSMV',
#   'MSV',
#   'TGMV',
#   'WDV',
#   'SSV',
#   'BCTV',
#   'SpV1',
#   'SpV4',
#   'RAM-1',
#   'MRV-1',
#   'MRV-2',
#   'MRV-3',
#   'AHSV-9',
#   'AHSV',
#   'BTV-2',
#   'CPV',
#   'RGDV',
#   'WTV',
#   'MRDV',
#   'RBSDV',
#   'RDV',
#   'IBDV',
#   'IPNV',
#   'UmV-P4',
#   'UmV-P6',
#   'ONN',
#   'RRV',
#   'VEE',
#   'EAV',
#   'LDV',
#   ['PRRSV-1', 'PRRSV1'],
#   'TBEV',
#   'LGT',
#   'LI',
#   'BVDV',
#   'BDV-1',
#   'HCV',
#   'HCV-H',
#   'IBV',
#   ['BCV', 'BECV'],
#   'FIPV',
#   'FECV',
#   'HCoV-229E',
#   'MHV',
#   'MHV-S',
#   'TGEV',
#   'TCV',
#   'BEV',
#   'NDV',
#   ['SV-5', 'SV5'],
#   ['HPIV-1', 'HPIV1'],
#   ['HPIV-2', 'HPIV2', 'PIV-2'],
#   ['HPIV-3', 'HPIV3'],
#   ['HPIV4a', 'PIV-4A'],
#   'HPIV4',
#   ['HPIV4b', 'PIV-4B'],
#   'CDV',
#   'RDV',
#   ['BRS', 'BRSV'],
#   'HRSV-B',
#   'HRSV-A',
#   'MBG',
#   'CHP',
#   'PIRY',
#   'VSIV',
#   'VSNJV',
#   'VHSV',
#   'IHNV',
#   'SIGMAV',
#   'SYNV',
#   'FPV',
#   'FLUAV',
#   'FLUBV',
#   'FLUCV',
#   'RVFV',
#   ['TOS', 'TOSV'],
#   'UUK',
#   'UUKV',
#   'CCHFV',
#   'INSV',
#   'TSWV',
#   'TACV',
#   'SFV-11',
#   'SFV-3',
#   'FIV',
#   'CAEV',
#   'EIAV',
#   ['HIV1', 'HIV', 'LAV-1'],
#   ['HIV2', 'HIV', 'LAV-2'],
#   'CIV',
#   ['HTLV-4', 'HTLV-IV'],
#   ['STLV-3', 'STLV-3agm'],
#   'SIV-AGM',
#   'SIV-AGM',
#   'SIV-AGM',
#   'SIV-AGM',
#   'SIV-AGM',
#   'SIV-MAC',
#   'SIV-MAC',
#   'SIV-MAC',
#   'SIV-MAC',
#   ['JSRV', 'OPAV'],
#   'MMTV',
#   'FESV',
#   'GA-FESV',
#   'SM-FESV',
#   'F-MULV',
#   'MCF',
#   'MLV',
#   'MMLV',
#   'SSAV',
#   'GALV',
#   'SFFV',
#   'MPMV',
#   'SMRV',
#   'SMRV-H',
#   'ALV',
#   'AMV',
#   'Y73SV',
#   'BLV',
#   ['HTLV-1', 'HTLV-I'],
#   ['HTLV-2', 'HTLV-II'],
#   'EV-2',
#   'MAV',
#   'LPDV',
#   'RHDV',
#   'RHDV-V351',
#   'FCV',
#   'VESV',
#   'CarMV',
#   'MNSV',
#   'TCV',
#   'BYDV',
#   'BLRV',
#   'BWYV',
#   'PLRV',
#   'TNV',
#   'EC-9-V',
#   'E6',
#   'BEV',
#   'CVA9',
#   'CVB1',
#   'CVB3',
#   'CVB4',
#   'CVB5',
#   'E11',
#   ['HPV-1', 'PV1'],
#   'HPV-2',
#   'HPV-3',
#   'HAV',
#   'EMCV',
#   'FMDV',
#   'HRV-2',
#   'HRV-14',
#   'HRV-89',
#   'HRV-1A',
#   'HRV-1',
#   'HRV-23',
#   'MCMV',
#   'SBMV',
#   'AMCV',
#   'CNV',
#   'TBSV',
#   'BMDV',
#   'TYMV',
#   ['BYV', 'SBYV'],
#   'CLV',
#   'PVM',
#   'HelVS',
#   'LSV',
#   'ACLSV',
#   'CYMV',
#   'NMV',
#   'PMV',
#   'PAMV',
#   'PVX',
#   'SMYEaV',
#   'WClMV',
#   'BCMV',
#   'BYMV',
#   'ClYVV',
#   'CABMV',
#   'GarMV',
#   'GSMV',
#   'LMV',
#   'MDMV',
#   'PRSV',
#   'PSbMV',
#   'PEMV',
#   'PeSMV',
#   'PPV',
#   'PVA',
#   'PVY',
#   'PVY(N)',
#   'SbMV',
#   'SCMV',
#   'SCMV-SC',
#   'TamMV',
#   'TEV',
#   'TVMV',
#   'TBV',
#   'TuMV',
#   'ZYMV',
#   'CCGMV',
#   'ORSV',
#   'TMV',
#   'BYNVV',
#   'BPMV',
#   'RCMV',
#   'CPMV',
#   'RCNMV',
#   'AMV',
#   'GCMV',
#   'TBRV',
#   'TOMRSV',
#   'BBV',
#   'TRV',
#   'BMV',
#   'CCMV',
#   'CMV',
#   'TAV',
#   'TSV',
#   'ApMV',
#   'AMV',
#   'BSMV',
#   'PSLV',
#   'MSTV',
#   'RSV',
#   'ScV-M1',
#   'RBDV',
#   'BDV',
#   'HAstV-1',
#   'BaYMV',
#   'CFDV',
#   'CHV1',
#   'JcDNV',
#   'LRV1-4',
#   'LRV1',
#   'BBTV',
#   'CLRV',
#   'CAV',
#   'EHV-2',
#   'FEV',
#   'H-Ast2',
#   'ADRV',
#   'HIV',
#   'HERV 1',
#   'IFV',
#   'MHV-4',
#   'PYFV',
#   'RRV',
#   'STMV',
#   'HSVd',
#   'PSTV',
#   'CVd-IV',
#   'CBLVd',
#   'Hh1',
#   'HAdV-E',
#   'CpGV',
#   'SFS',
#   'HHBV',
#   ['AmEPV', 'AMEV'],
#   'CfEPV',
#   'HTLV-3',
#   'PRRSV',
#   'ASGV',
#   'PCV',
#   'ORSV',
#   'UmVH1',
#   ['Hz-1', 'HzNOB'],
#   'GLV',
#   'TVV',
#   ['BCV-3', 'BCV3'],
#   'DMV',
#   'TVCV',
#   'sTobRV RNA',
#   'AgMNPV',
#   'BCaMV',
#   'CFA',
#   ['CVA-16', 'CVA16'],
#   'PWV',
#   'JGMV',
#   'HEV',
#   'ShVX',
#   'SaHV-2',
#   'HLO',
#   'MrV',
#   'LYNV',
#   'SrMV',
#   'TTBV',
#   'TBBV',
#   'ReTBV',
#   'LiMV',
#   'MBV',
#   'IPCV',
#   ['AHV-1', 'AlHV1', 'BHV3'],
#   'MuHV-4',
#   'AHSV-1',
#   'MARV-Mus',
#   ['STLV-1', 'STLV-I'],
#   'MDV1',
#   'MDV6',
#   'SV7',
#   'TV24',
#   'CVA2',
#   'GRAV',
#   'HF2',
#   'BCG',
#   'MLOs',
#   'PAdV-3',
#   'ASV31',
#   'HIV',
#   'PLCV',
#   'RTSV',
#   'SJNNV',
#   'HAstV-4',
#   'AgDV',
#   'MPV-1',
#   'ASPV',
#   'PVYV',
#   'HAstV-3',
#   'HAstV-5',
#   'LfWB',
#   'MDV2',
#   'ArNPV',
#   'CV-XZ6E',
#   ['FLCDV', 'FLDV', 'LCDV'],
#   'HTLV-IIB',
#   'STLV-1F',
#   'HCV-Hun',
#   'AHSV-4',
#   'CeHV-5',
#   'SCSV',
#   'LRMV',
#   'CiLRV',
#   'CVV',
#   'HAstV-6',
#   'GmDV',
#   'SRSV',
#   'HMV-2',
#   ['HHV8', 'KSHV'],
#   'DpRV',
#   'PVV',
#   'HERV-K',
#   'PNRSV',
#   'HTLV-IIA',
#   'MnNPV',
#   'SHFV',
#   'SAdV-3',
#   ['PenuNPV', 'PnMNPV'],
#   'YMTV',
#   'HAstV-7',
#   'CsCMV',
#   ['EV-71', 'EV71'],
#   ['PTLV', 'STLV', 'STLV-L'],
#   'GBV-B',
#   'LRV2-1',
#   'LRV1-13',
#   'FsV',
#   'AHV3',
#   'AV-2',
#   'CHV2-NB58',
#   'BPV-5',
#   'AgMV',
#   'HoMV',
#   'E30',
#   'CVd-IIIa',
#   'CVd-III',
#   'CVd-IIIb',
#   'ASHV',
#   ['HEV', 'PHEV'],
#   'ILV',
#   'RRSV',
#   'ScV-La',
#   'BStV',
#   'SPLV',
#   'CVA10',
#   'CVA13',
#   'CVA14',
#   'CV-A17',
#   'CVA20',
#   ['CVA-4', 'CVA4'],
#   'CVA5',
#   'HdMV',
#   'EMoV',
#   'MPV-1b',
#   'MPV-1c',
#   'HaPV',
#   'OYDV',
#   'BCMNV',
#   'Mtv30',
#   'HAstV-8',
#   'BFNNV',
#   'RGNNV',
#   'TPNNV',
#   'CNPV',
#   'AYVV',
#   'ArceNPV',
#   'PAR',
#   'E25',
#   'OGSV',
#   'GTOV',
#   'LWSV',
#   'HvV-190S',
#   'BmDNV-2',
#   'LLAP 2',
#   'LLAP 7',
#   'LLAP 9',
#   'DlEV',
#   'SAV',
#   'SDNV',
#   'SORV',
#   'AcMNPV',
#   'E7',
#   ['CV-NC1A', 'CV-NC64A'],
#   ['PBCV NY2A', 'PBCV-NY2A'],
#   'HRV-5',
#   'PCV',
#   'HrCTV',
#   'BRV',
#   'PmNOB III',
#   ['SA12', 'SV12'],
#   'CTFV',
#   'ERAV',
#   'ERBV-1',
#   'TSEV',
#   'PhHV-1',
#   'P0HV-2',
#   'E16',
#   'E17',
#   'E19',
#   'E20',
#   'E32',
#   'E3',
#   'TAV-1',
#   'TPV',
#   'CdTV',
#   'GCLV',
#   'CeHV-8',
#   'GLRaV-1',
#   'NLV',
#   'MacMV',
#   'AHSV2',
#   'LLAP 1',
#   'LLAP 8',
#   'BBWV-1',
#   'RB42',
#   'LLAP 14',
#   'WiMV',
#   ['ChlVMV', 'PVBV'],
#   'CLCuV',
#   'ScSMV',
#   ['GBV-C', 'GBV-C/G', 'HGV-1', 'HGV'],
#   ['BVDV-2', 'BVDV type II'],
#   'IPPYV',
#   'MOBV',
#   'Twort',
#   '187',
#   'CVbMV',
#   'MAI',
#   'ISAV',
#   'SBRV',
#   'OBDV',
#   'CfGV',
#   'HERV-H',
#   'AAV-4',
#   ['HIV', 'SHIV'],
#   'SCSV',
#   'LRV1-1',
#   'LeMV',
#   'VSH-1',
#   'SAG',
#   ['RTYV', 'RYSV'],
#   'LSDV',
#   'ILHV',
#   'MRFV',
#   'MUCV',
#   'VEEV-IIIB',
#   'PERV',
#   'EACMV',
#   'EyV',
#   'MSRV',
#   'HERV-W',
#   'SHEV',
#   'PEV-9',
#   'DCV',
#   'APOIV',
#   'BUBV',
#   'DBV',
#   'ENTV',
#   'KSIV',
#   'BAGV',
#   'ITV',
#   'NTAV',
#   'BOUV',
#   'UGSV',
#   'CRV',
#   'JUTV',
#   'MODV',
#   'SVV',
#   'PPBV',
#   'ZIKV',
#   'WEHV2',
#   'WEHV1',
#   'PMoV',
#   'PRMV',
#   'WisiNPV',
#   'CGRMV',
#   'CtRLV',
#   'TINV',
#   'RGSV',
#   'TYLCV-Is',
#   'APSE-1',
#   'MVDV',
#   'ToCV',
#   'CPMMV',
#   'TbLCV',
#   'BSV',
#   'BLHV',
#   'DYMV',
#   'OkMV',
#   'DuMV',
#   'WCMV',
#   'AgIV',
#   'CWL-S',
#   'BusuNPV',
#   'FUPO-1',
#   'MDEV',
#   'WBNV',
#   'BSBMV',
#   'GBV-A',
#   'FDV',
#   'BFDV',
#   'ATV',
#   'CVB2',
#   'EHNV',
#   'PCV2',
#   'SCLV',
#   ['CVA-6', 'CVA6'],
#   'ToYMoV',
#   'EEHV1',
#   'EEHV2',
#   'PLHV-2',
#   'CABYV',
#   'WSSV',
#   'LiLV',
#   'TLMV',
#   'YHV',
#   'DPWT',
#   'ScRS',
#   'SLY',
#   'SGP',
#   'PfDV',
#   'BDV-2',
#   'TGV-Ub',
#   'FrMV',
#   'JHP',
#   'GFkV',
#   'HpLV',
#   'Chp-2',
#   ['CalHV-3', 'CalHV3'],
#   'PEV-10',
#   'SRV-6',
#   'SgCSV',
#   'DiVY',
#   'KGMMV',
#   'CVX',
#   'HRSV',
#   'PepMV',
#   'ONMV',
#   'HvAV-3a',
#   'HvAV-3b',
#   'HvAV-3c',
#   'HvAV-3d',
#   ['SfAV-1a', 'SfAV-1'],
#   'SfAV-1c',
#   'EV-75',
#   'PVY(NTN)',
#   'ROPV',
#   'GHPyV',
#   ['TYLCSarV', 'TYLCSV'],
#   'His1V',
#   'His2V',
#   'His2',
#   'BRMV',
#   ['SEBOV', 'SUDV'],
#   'GCRV',
#   ['CIEBOV', 'TAFV'],
#   ['REBOV', 'RESTV'],
#   'CNRMV',
#   'CIV',
#   'BFDV',
#   'CpHV-2',
#   'PtRV-1',
#   'MHV-72',
#   'TBSV-P DI-4',
#   'TBSV-P DI-5',
#   'MHV-1',
#   'PEV-J10',
#   'HpMV',
#   'WMV2',
#   'HRV-B84',
#   'TAMV',
#   'SIV-2',
#   'PcDV',
#   'Mtv-17',
#   'ERBV-2',
#   'CaHV-1',
#   'CSFV39',
#   'SV42',
#   ['BmNPV', 'BmSNPV'],
#   'FAdV 11',
#   'AHV5',
#   'CYMVR',
#   'SAdV-22',
#   'CmYLCV',
#   'CBPV',
#   'EhV-86',
#   'CavPIV-3',
#   'AOPRV',
#   'SCMV-AOP',
#   'MIDNV',
#   'PiNDV',
#   'CpDNV',
#   'CpDV',
#   'AdDNV',
#   'AdDV',
#   'TYLCCNV',
#   'ZEBOV',
#   'PTV',
#   'PEMV',
#   'HPEV-3',
#   'RYMV sc-RNA',
#   'SCPMV',
#   'PLHV3',
#   'SFNV',
#   'THEV',
#   'CYVMV',
#   'CfMNPV',
#   'Bcep781',
#   'PsV-S',
#   'LYCIV',
#   'LChV',
#   'SqLCV-C',
#   'AZ79',
#   'BDV-3',
#   'AAAV VR-865',
#   'BgDV1',
#   'Influenza A virus (A/Taiwan/1/62(H2N2))',
#   'SbarLHV-1',
#   'CLCuKV',
#   'EV-74',
#   'SiGMFV-US',
#   ['HCoV-SARS', 'SARS', 'SARSr-CoV', 'SARSrCoV'],
#   'SARS Tor2',
#   'GSDIV',
#   'BVDV-0',
#   ['CpMYRV-1/9B21', 'MYRV1-9B21'],
#   'VDV-1',
#   'RnW8V-M',
#   'IWSV',
#   'PafrLHV-1',
#   'EoPV',
#   'EoV',
#   'HYVV-[UK1]',
#   'HYVV-[UK2]',
#   'SSV1',
#   'SSV2',
#   'SGNNV',
#   'HXHV',
#   'NRV',
#   'SWBV',
#   'OpMNPV',
#   'IHHNV',
#   'TRBIV',
#   'CLCuKV-Dab',
#   'SBIV-K',
#   'RBIV-K',
#   'RSIV-K',
#   'A/Eg/HK/757.3/02',
#   'Prophage Gifsy-3',
#   'Lamprosphaerus sp. JGZ-2004-1',
#   'STSV1',
#   'IAPVOB',
#   'Saproscincus sp. Eungella',
#   'GmNPV',
#   'RHDV-SD',
#   'RHDV-FRG',
#   'RHDV-BS89',
#   'RHDV-AST89',
#   'ATV',
#   'EBHSV-GD',
#   'PVYNW',
#   'TIBV',
#   'OVRV',
#   'BiMV',
#   'OSGIV',
#   'NDiV',
#   'RLMV',
#   'BmDNV-3',
#   'HPV16',
#   'BPV-1',
#   'SFV-1',
#   'BCRV',
#   'APSE-2',
#   'HVP2',
#   'HMTV',
#   ['PBCV MT325', 'PBCV-MT325'],
#   'Cilv-C',
#   'LmjF',
#   'Bcep176',
#   'CPyV',
#   'FLMaV-1',
#   ['DHV-3', 'DHV3'],
#   '936',
#   'XMRV-VP35',
#   'XMRV',
#   'XMRV-VP42',
#   'ev/J',
#   'ALV-A',
#   'FECV-MSU1',
#   'XMRV-VP62',
#   'Influenza A virus (A/swine/Fujian/01(H5N1))',
#   'RAVV-Rav',
#   'GpSGHV',
#   'OBOV',
#   'ZYFV',
#   'McPV2',
#   'FLMaV-2',
#   'HBVcpz',
#   'ToLCBV-[IN:KerIV:05]',
#   'HRSV-S2',
#   'SV39',
#   'KARV',
#   'ToLCHsV-[TW:THsi:05]',
#   'ToLCTWV-[TW:Hsi:C1:05]',
#   'CaYMV',
#   'ToLCRajV-[IN:Raj:05]',
#   'SpiMV-2',
#   'Bat CoV HKU9',
#   'HRV-AMS323',
#   'HEV-AMS721',
#   'HEV-AMS573',
#   'RDCoV/GZ43/03',
#   'CFBCoV/DM95/03',
#   'HRV-C3',
#   'PDTWII',
#   ['EePV1', 'EHPV1'],
#   'SIV-wrc',
#   'LBBV',
#   'Odorrana tiannanensis (Yang and Li, 1980)',
#   'SqPyV',
#   'HIRRV',
#   'CEVd-Sj 1',
#   'CEVd-Sj 2',
#   'TFRSV',
#   'PmV1',
#   'RHBV-cr',
#   'MARV-Ozo',
#   'FlPV1',
#   'MeYVMV-[IN:Bar2:06]',
#   'HTCV',
#   'MdSGHV',
#   'EcPV2',
#   'phiCP39-O',
#   'BFNNV-BF93Hok',
#   'Influenza A virus (A/Ck/UP/India/2543/2004(H9N2))',
#   'LbFV',
#   'UMBV',
#   'BDBV',
#   'DHV2',
#   'pSIVgml',
#   'AYLCuB-[PK:Lhr:2005]',
#   'SAdV-37',
#   'FAdV-8a',
#   'FAdV-8b',
#   'HCoSV',
#   'HCoSV-A',
#   'HCoSV-B',
#   'HCoSV-C',
#   'HCoSV-D',
#   'HCoSV-E',
#   'RELIK',
#   'GSyV-1',
#   'ButMV',
#   'BatBHV-2',
#   'phiCP26F',
#   'TTSV1a',
#   'TTSV1b',
#   'CroV',
#   'BtAdV-2 strain PPV1',
#   'SVC',
#   'MOUV',
#   'Silurana sp. BOLD:AAH0940',
#   'AAI',
#   'HHPV-1',
#   'HHPV-1',
#   'CSLPyV',
#   'HPV-150',
#   'HPV-151',
#   'XMRV 22Rv1/CWR-R1',
#   'STIV2',
#   'CnP-PARV4',
#   'BpPV1',
#   'CPV',
#   'PBoV1',
#   'PBoV2',
#   ['EV-C109', 'HEV109'],
#   'TSPyV',
#   'CHV-1',
#   'TNV-1',
#   'TNV-2',
#   'SiGMFV-MA',
#   'PasV-A1',
#   'CaPyV',
#   'CpCV-A',
#   'CpCV',
#   'CpCV-B',
#   'CpRLV',
#   'KLAV',
#   'SAdV-18',
#   'PBoV-SX',
#   'MCG',
#   'SPCV',
#   'UCBSV',
#   'HPeV10',
#   'HPeV11',
#   'THV',
#   'ToLCMGVMen[MG:Mor:01]',
#   'ToLCMGVAnd[MG:Tol:01]',
#   ['PEV-8', 'PEV-J4', 'PEV-J6'],
#   'SFTSV',
#   'SFTSV',
#   'ChiLCB-[IN:Pal:08]',
#   'SC50',
#   'AfuPV-1',
#   'PBoV3',
#   'PBoV4',
#   'phiCP13O',
#   'PhiCP34O',
#   'phiCP9O',
#   'CAV',
#   'HPV126',
#   'HAdV 61',
#   'FRCoV-511c',
#   'FRCoV-4E98',
#   'SfAV-1d',
#   'PBoV4-1',
#   'PBoV4-2',
#   'HAdV 65',
#   'ESV',
#   'PhaHV-1',
#   'Eh-BtPV-1',
#   'TTFeV-Fc-TTV2',
#   'TTFeV-Fc-TTV1',
#   'HRPV-2',
#   'HRPV-3',
#   'HRPV-6',
#   'HGPV-1',
#   'APSV',
#   'CePV-1',
#   'TYDV-C',
#   'XdV-L1A',
#   'XdV-L1B',
#   'XdV-L2',
#   'DEDSV',
#   'GyV4',
#   'HRTV',
#   'TTSVk2',
#   'RHEph1',
#   'RHEph2',
#   'CedPV',
#   'SPuV',
#   'HCosV RdRp-18',
#   'MERS',
#   'HX01',
#   'BtCoV_HKU10',
#   'SpexNPV',
#   'AchPV1',
#   'AchPV2',
#   'RoV-A1',
#   'KLCuB',
#   'VmPyV3',
#   'VmPyV1',
#   'VmPyV2',
#   'SVIV',
#   'CnBoV3',
#   'EV99',
#   'GaCSV',
#   'ROUTV',
#   'TDAV',
#   'CRMaV',
#   'CvHV3',
#   'BtCoV_CDPHE15',
#   ['Skermanella aerolata 5416T-32', 'Skermanella aerolata DSM 18479'],
#   'as5',
#   'AelPyV1',
#   'AdMDV',
#   'TOgMV',
#   'SiDV',
#   'HRV-C39',
#   'EhV145',
#   'EhV156',
#   'EhV164',
#   ['EhV-18', 'EhV18'],
#   'DfIV',
#   'TIBOV',
#   'FTLSV',
#   'HHPV-2',
#   'HPV178',
#   'NJ-PyMv-2013',
#   'RoV-A2',
#   'HBoV2a-TU',
#   'HBoV2b-NI',
#   'HBoV2c-PK',
#   'HBoV4-NI',
#   'PBoV-A6',
#   'AalDV2',
#   'PstDV1',
#   'RoTTV1',
#   'RoTTV2',
#   'DcPV',
#   'TiLV',
#   'WRSV',
#   'SMSV-8',
#   ...],
#  'genbank_common_name': ['eubacteria',
#   'aphid P-endosymbionts',
#   'fruiting gliding bacteria',
#   'Lyme disease spirochete',
#   'syphilis treponeme',
#   'yaws treponeme',
#   'fluorescent pseudomonads',
#   'son-killer infecting Nasonia vitripennis',
#   'rickettsias',
#   'heartwater rickettsia',
#   'agent of rickettsialpox',
#   'Potomac horse fever agent',
#   'cat scratch disease bacillus',
#   'purple sulfur bacteria',
#   'purple nonsulfur bacteria',
#   'filamentous anoxygenic phototrophic bacteria',
#   'blue-green algae',
#   'lactic streptococci',
#   "Tyzzer's bacillus",
#   "Quin's oval",
#   'Coryneform bacteria',
#   'high G+C Gram-positive bacteria',
#   'sweet orange',
#   'eucaryotes',
#   'red algae',
#   'carragheen',
#   'asakusa nori',
#   'laver',
#   'susabi-nori',
#   'Dulse',
#   'golden algae',
#   'yellow-green algae',
#   'diatoms',
#   'marine diatom',
#   'dinoflagellates',
#   'alveolates',
#   'brown algae',
#   'Atlantic wakame',
#   'cryptomonads',
#   'euglenids',
#   'green algae',
#   'hollow green seaweed',
#   'sea lettuce',
#   'liverworts',
#   'liverwort',
#   'mosses',
#   'spike mosses',
#   'clubmosses',
#   "Martens's spike moss",
#   "stag's-horn clubmoss",
#   'horsetails',
#   'horstails',
#   'field horsetail',
#   'giant horsetail',
#   'turnip fern',
#   'ostrich fern',
#   'cinnamon fern',
#   'cycads',
#   "Altenstein's bread tree",
#   'maidenhair tree',
#   'fir trees',
#   'deodar cedar',
#   'larches',
#   'tamarack',
#   'western larch',
#   'Norway spruce',
#   'white spruce',
#   'Colorado spruce',
#   'Sitka spruce',
#   "Engelmann's spruce",
#   'foxtail pine',
#   'lodgepole pine',
#   'pinyon',
#   "Krempf's pine",
#   'sugar pine',
#   'Western white pine',
#   'stone pine',
#   'Monterey pine',
#   'Eastern white pine',
#   'Scots pine',
#   'Japanese black pine',
#   'loblolly pine',
#   'Douglas-fir',
#   'hemlocks',
#   'western hemlock',
#   'Japanese cedar',
#   'flowering plants',
#   'cucumber-tree',
#   'avocado',
#   'California bay',
#   'Japanese goldthread',
#   'love-in-a-mist',
#   'buttercups',
#   'tall buttercup',
#   "virgin's bower",
#   'serendipity berry',
#   'pink corydalis',
#   'California poppy',
#   'opium poppy',
#   'bloodroots',
#   'red puccoon',
#   'Japanese hop',
#   'European hop',
#   'jackfruit',
#   'figs',
#   'common fig',
#   'Osage orange',
#   'mulberries',
#   'white mulberry',
#   'great nettle',
#   'European white birch',
#   'paper birch',
#   'river birch',
#   'northern red oak',
#   'white oak',
#   'European green alder',
#   'swamp oak',
#   'American pokeweed',
#   'food pokeweed',
#   "garden four-o'clock",
#   'common iceplant',
#   'red goosefoot',
#   'spinach',
#   'amaranth',
#   'clove pink',
#   'soapwort',
#   'common soapwort',
#   'campions',
#   'common buckwheat',
#   'bitter dock',
#   'garden rhubarb',
#   'China jute',
#   'sea-island cotton',
#   'cotton',
#   'cacao',
#   'Brazil nut',
#   'papaya',
#   'red bryony',
#   'muskmelon',
#   'oriental pickling melon',
#   'cantaloupe',
#   'cucumber',
#   'marrows',
#   'winter squash',
#   'crookneck pumpkin',
#   'vegetable marrow',
#   'zucchini',
#   'white-flowered gourd',
#   'smooth loofah',
#   'balsam apple',
#   'bitter melon',
#   'spiny bitter cucumber',
#   'jumping cucumber',
#   'passionflowers',
#   'granadilla',
#   'poplars',
#   'quaking aspen',
#   'black cottonwood',
#   'mustard family',
#   'thale cress',
#   'rape',
#   'black mustard',
#   'field mustard',
#   'wild cabbage',
#   'kale',
#   'Chinese kale',
#   'cabbage',
#   "shepherd's purse",
#   'common stock',
#   'radish',
#   'white mustard',
#   'horseradish tree',
#   'strawberry',
#   'apple',
#   'almond',
#   'bitter almond',
#   'plum',
#   'peach',
#   'pears',
#   "camel's foot tree",
#   'bead tree',
#   'silk tree',
#   'Indian licorice',
#   'peanut',
#   'pigeon pea',
#   'jack bean',
#   'sword bean',
#   'chickpea',
#   'sunn hemp',
#   'smooth rattlebox',
#   'guar',
#   'mucana',
#   'cowpea',
#   'coral bean',
#   'soybean',
#   'Scotch laburnum',
#   'yellow vetchling',
#   'flat-pod pea',
#   'rough pea',
#   'yellow-flowered pea',
#   'sweet pea',
#   'spring vetchling',
#   'Tangier pea',
#   'lentil',
#   'white popinac',
#   'winged pea',
#   'white lupine',
#   'narrow-leaved blue lupine',
#   'tree lupine',
#   'yellow lupine',
#   'large-leaved lupine',
#   'medics',
#   'sickle medic',
#   'barrel medic',
#   'common sainfoin',
#   'lima bean',
#   'pea',
#   'winged bean',
#   'kudzu vine',
#   'Japanese pagoda tree',
#   'white clover',
#   'furze',
#   'bird vetch',
#   'fava bean',
#   'hairy vetch',
#   'adzuki bean',
#   'black gram',
#   'mung bean',
#   'cowpea',
#   'Japanese wisteria',
#   'cider tree',
#   'evening primroses',
#   'Appalachian evening primrose',
#   'German evening primrose',
#   'oil nut',
#   'showy mistletoe family',
#   'Columbian mistletoe',
#   'Argentine mistletoe',
#   'California mistletoe',
#   'American mistletoe',
#   'European mistletoe',
#   'rubber tree',
#   'cassava',
#   "dog's mercury",
#   'castor bean',
#   'spurges',
#   'leafy spurge',
#   'flax',
#   'nasturtium',
#   'maple trees',
#   'box elder',
#   'sugar maple',
#   'Norway maple',
#   'sycamore maple',
#   'carrot',
#   'parsnip',
#   'parsley',
#   'coriander',
#   'water pennyworts',
#   'lawn water-pennywort',
#   'Madagascar periwinkle',
#   'serpentwood',
#   'mudar',
#   'peppers',
#   'sacred datura',
#   'jimsonweed',
#   'henbane',
#   'tomato',
#   'acuminate tobacco',
#   'Persian tobacco',
#   "Bigelov's tobacco",
#   "Debney's tobacco",
#   'tree tobacco',
#   'curled-leaved tobacco',
#   'Aztec tobacco',
#   'wood tobacco',
#   'common tobacco',
#   'Chaco potato',
#   "Commerson's wild potato",
#   'Chilean potato-tree',
#   'eggplant',
#   'black nightshade',
#   'potato',
#   'sweet potato',
#   'common morning-glory',
#   'dodders',
#   'southern Asian dodder',
#   'Swedish begonias',
#   'common olive',
#   'jasmines',
#   'snapdragons',
#   'snapdragon',
#   'monkey flowers',
#   'spotted monkey flower',
#   'foxgloves',
#   'common foxglove',
#   'Kenilworth ivy',
#   'speedwells',
#   'beechdrops',
#   'sesame',
#   'European elder',
#   'common ragweed',
#   'giant ragweed',
#   'burdocks',
#   'great burdock',
#   'safflower',
#   'Niger seed',
#   'common sunflower',
#   'witch hazels',
#   'Chinese witch hazel',
#   'sweet gum trees',
#   'sweet gum',
#   'water-lilies',
#   'sacred lotus',
#   'leadwort',
#   'monocotyledons',
#   'giant taro',
#   'cuckoopint',
#   'taro',
#   'voodoo lily',
#   'duckweed',
#   'swollen duckweed',
#   'water lettuce',
#   'small naked oat',
#   'oats',
#   "Job's tears",
#   'orchard grass',
#   'finger millet',
#   'seaside barley',
#   'Italian ryegrass',
#   'rice',
#   'malo sina',
#   'African rice',
#   'bluegrass',
#   'Kentucky bluegrass',
#   'rye',
#   'foxtail millet',
#   'sorghum',
#   'gama grass',
# ...
#   ['Clostridium thermautotrophicum', 'Clostridium thermoautotrophicum'],
#   ['Acuformis perennis',
#    'Clostridium barati',
#    'Clostridium paraperfringens',
#    'Clostridium perenne'],
#   ['Desulfotomaculum orientis', 'Desulfovibrio orientis'],
#   ['Clostridium nigrificans',
#    'Desulfotomaculum carboxydivorans',
#    'Sporovibrio desulfuricans'],
#   'Desulfotomaculum australicum',
#   'Sporosarcina halophila',
#   ['Planosarcina ureae', 'Sarcina ureae'],
#   'Clavibacter xyli',
#   'Paralactobacillus',
#   ['Bacillus acidophilus', 'Thermobacterium intestinale'],
#   ['Bacillus casei g',
#    'Bacillus g',
#    'Betabacterium breve',
#    'Lactobacillus brevis',
#    'Lactobacterium breve'],
#   ['Bacillus Buchneri',
#    'Bacterium buchneri',
#    'Lactobacillus buchneri',
#    'Lactobacterium buchneri',
#    'Ulvina buchneri'],
#   ['Bacillus a',
#    'Bacillus casei a',
#    'Bacterium casei a',
#    'Caseobacterium vulgare',
#    'Lactobacillus casei subsp. casei',
#    'Lactobacillus casei',
#    'Lactobacterium casei',
#    'Streptobacterium casei'],
#   ['Lactobacillus confusus', 'Lactobacillus coprophilus subsp. confusus'],
#   ['Bacillus acidificans longissimus',
#    'Bacillus Delbrucki',
#    'Bacterium delbrucki',
#    'Lactobacillus delbrucki',
#    'Lactobacterium delbrucki',
#    'Plocamobacterium delbrucki',
#    'Thermobacterium cereale',
#    'Ulvina delbrucki'],
#   ['Lactobacillus bulgaricus',
#    'Lactobacillus delbrueckii bulgaricus',
#    'Lactobacillus delbrueckii (SUBSP. BULGARICUS)',
#    'Thermobacterium bulgaricum'],
#   ['Bacillus casei e',
#    'Bacillus e',
#    'Caseobacterium e',
#    'Lactobacillus helveticum',
#    'Lactobacillus suntoryeus',
#    'Lactobacterium helveticum',
#    'Plocamobacterium helveticum',
#    'Thermobacterium helveticum'],
#   'Lactobacillus Type II',
#   'Lactobacillus pentosus',
#   ['Lactobacillus arabinosus',
#    'Lactobacillus arizonensis',
#    'Lactobacillus plantari',
#    'Lactobacillus plantarum',
#    'Lactobacterium plantarum',
#    'Streptobacterium plantarum'],
#   ['Lactobacillus 30A', 'Lactobacillus sp. (strain 30A)'],
#   'Lactobacillus paracasei',
#   ['Lactobacillus fermentum biotype II',
#    'Lactobacillus fermentum subsp. reuteri',
#    'Lactobacillus reuteri'],
#   ['Lactobacillus bavaricus',
#    'Lactobacillus sake (sic) Katagiri et al. 1934 (Approved Lists 1980)'],
#   'Lactobacillus agilis',
#   'Lactobacillus alimentarius',
#   'Lactobacillus amylophilus',
#   ['Lactobacillus acidophilus group A3', 'Lactobacillus sobrius'],
#   'Lactobacillus animalis',
#   'Lactobacillus aviarius',
#   'Lactobacillus bifermentans',
#   'Lactobacillus coryniformis',
#   'Lactobacillus farciminis',
#   ['Bacillus casei d',
#    'Bacillus d',
#    'Lactobacillus cellobiosus',
#    'Lactobacillus fermentum',
#    'Lactobacterium fermentum'],
#   ['Lactobacillus fructivorans ATCC 8288',
#    'Lactobacillus fructivorans DSM 20203',
#    'Lactobacillus fructivorans JCM 1117',
#    'Lactobacillus fructivorans KCTC 3543 = DSM 20203',
#    'Lactobacillus fructivorans KCTC 3543',
#    'Lactobacillus fructivorans LMG 9201',
#    'Lactobacillus fructivorans',
#    'Lactobacillus heterohiochii',
#    'Lactobacillus homohiochii',
#    'Lactobacillus trichodes'],
#   ['Lactobacillus halotolerans',
#    'Lactobacillus viridescens subsp. halotolerans'],
#   'Lactobacillus kandleri',
#   ['Lactobacillus mali',
#    'Lactobacillus yamanashiensis subsp. mali',
#    'Lactobacillus yamanashiensis subsp. yamanashiensis',
#    'Lactobacillus yamanashiensis'],
#   ['Lactobacillus minor', 'Lactobacillus viridescens subsp. minor'],
#   'Lactobacillus murinus',
#   'Lactobacillus ruminis',
#   'Lactobacillus salivarius',
#   ['Lactobacillus sanfranciscensis', 'Lactobacillus sanfrancisco'],
#   'Lactobacillus sharpeae',
#   "'Lactobacillus thermophilus'",
#   ['Betabacterium vermiforme', "'Lactobacillus vermiforme'"],
#   'Lactobacillus viridescens',
#   'Lactobacillus vitulinus',
#   ['Lactobacillus fructosus',
#    'Leuconostoc fructosum',
#    'Leuconostoc fructosus'],
#   'Lactobacillus oris',
#   'Lactobacillus vaginalis',
#   ['Lactobacillus sake l45', 'Lactobacillus sake (strain l45)'],
#   'Listerella',
#   ['Listeria bulgarica',
#    'Listeria monocytogenes subsp. perhaemolytica',
#    'Listeria perhaemolytica'],
#   ['Bacterium monocytogenes hominis',
#    'Bacterium monocytogenes',
#    'Corynebacterium infantisepticum',
#    'Corynebacterium parvulum',
#    'Erysipelothrix monocytogenes',
#    'Listerella hepatolytica'],
#   ['Listeria grayi murrayi',
#    'Listeria grayi subsp. grayi',
#    'Listeria murrayi',
#    'Murraya grayi'],
#   'Erysipelothrix group',
#   ['Bacillus insidiosus',
#    'Bacillus rhusiopathiae suis',
#    'Bacterium rhusiopathiae',
#    'Erysipelothrix erysipeloides',
#    'Erysipelothrix insidiosa',
#    'Erysipelothrix murisepticus',
#    'Erysipelothrix porci'],
#   'Zopfius',
#   ['Bacillus zopfii',
#    'Bacterium zopfii',
#    'Helikobacterium zopfii',
#    'Zopfius zopfii'],
#   'Alloiococcus otitidis',
#   ['Corynebacterineae', 'Mycobacteriales'],
#   ['Actinocladothrix', 'Discomyces'],
#   'Odontomyces viscosus',
#   ['Actinomyces suis', 'Corynebacterium suis', 'Eubacterium suis'],
#   ['Actinocladothrix bovis',
#    'Cladothrix bovis',
#    'Discomyces bovis',
#    'Nocardia bovis',
#    'Oospora bovis',
#    'Proactinomyces bovis',
#    'Sarcomyces bovis',
#    'Sphaerotilus bovis',
#    'Streptothrix bovis'],
#   ['Actinobacterium israeli',
#    'Brevistreptothrix israeli',
#    'Cohnistreptothrix israeli',
#    'Corynebacterium israeli',
#    'Discomyces israeli',
#    'Nocardia israeli',
#    'Oospora israeli',
#    'Proactinomyces israeli',
#    'Streptothrix israeli'],
#   ['Actinomyces pyogenes',
#    'Arcanibacterium pyogenes',
#    'Arcanobacterium pyogenes',
#    'Bacillus pyogenes',
#    'Corynebacterium pyogenes'],
#   ['Achromobacter globiforme',
#    '"Achromobacter globiformis" (Conn 1928) Bergey et al. 1930',
#    'Bacterium globiforme',
#    'Corynebacterium globiforme',
#    'Mycobacterium globiforme'],
#   ['Arthrobacter NRRL B3728',
#    'Arthrobacter NRRL-B3728',
#    'Arthrobacter sp. (NRRL B3728)',
#    'Arthrobacter sp. (STRAIN NRRL B3728)'],
#   ['Arthrobacter oxidans', 'Arthrobacter oxydans'],
#   'Arthrobacter viscosus',
#   'Arthrobacter polychromogenes',
#   ['Bifidibacterium', 'Tissieria'],
#   'Bifidobacterium stercoris',
#   ['Actinobacterium bifidum',
#    'Actinomyces bifidus',
#    'Actinomyces parabifidus',
#    'Bacillus bifidus communis',
#    'Bacillus bifidus',
#    'Bacterium bifidum',
#    'Bacteroides bifidus',
#    'Bifidibacterium bifidum',
#    'Cohnistreptothrix bifidus',
#    'Lactobacillus bifidus type II',
#    'Lactobacillus parabifidus',
#    'Nocardia bifida',
#    'Tissieria bifida'],
#   ['Bifidobacterium infantis',
#    'Bifidobacterium lactentis',
#    'Bifidobacterium liberorum',
#    'Bifidobacterium longum bv. Infantis',
#    'Bifidobacterium longum infantis'],
#   'Bifidobacterium parvulorum',
#   'Actinomyces eriksonii',
#   'Bifidobacterium globosum',
#   ['Bifidobacterium longum bv. Suis',
#    'Bifidobacterium longum suis',
#    'Bifidobacterium suis'],
#   ['Bacterium ammoniagenes', 'Brevibacterium ammoniagenes'],
#   'Turicella',
#   "'Brevibacterium sterolicum'",
#   'Bacterium linens',
#   'Corynebacterium helvolum',
#   ['Achromobacter stationis', 'Brevibacterium stationis'],
#   'Bacterium fimi',
#   'Bacillus biazoteus',
#   ['Arthrobacter luteus',
#    'Brevibacterium fermentans',
#    'Brevibacterium lyticum',
#    'Cellulomonas cartae',
#    'Cellulomonas cartalyticum',
#    'Cellulomonas cellulans',
#    'Cellulosimonas cellulans',
#    'Nocardia cellulans',
#    'Oerskovia xanthineolytica'],
#   ['Aplanobacter flavigenum',
#    'Bacillus flavigena',
#    'Bacterium flavigena',
#    'Empedobacter flavigena',
#    'Pseudobacterium flavigenum'],
#   'Bacillus gelidus',
#   ['Cellulomonas turbata', 'Nocardia turbata'],
#   'Bacterium udum',
#   ['Bacillus diphtheriae',
#    'Bacterium diphtheriae',
#    'Microsporon diphthericum',
#    'Microsporon diphtheriticum',
#    'Mycobacterium diphtheriae',
#    'Pacinia loeffleri'],
#   ['Brevibacterium chang-fua',
#    'Brevibacterium divaricatum',
#    'Brevibacterium glutamigenes',
#    "'Brevibacterium lactofermentum'",
#    'Brevibacterium lactofermentum',
#    'Brevibacterium saccharolyticum',
#    'Brevibacterium seonmiso',
#    'Brevibacterium taipei',
#    'Brevibacterium thiogenitalis',
#    "'Corynebacterium lactofermentum'",
#    'Corynebacterium lactofermentum',
#    'Corynebacterium lilium',
#    'Micrococcus glutamicus',
#    'Micrococcus maripuniceus'],
#   ['Bacillus pseudotuberculosis-ovis',
#    'Bacillus pseudotuberculosis',
#    'Corynebacterium ovis',
#    'Corynebacterium preisz-nocardi',
#    'Corynebacterium pseudotuberculosis-ovis',
#    'Mycobacterium tuberculosis-ovis'],
#   'Turicella sp.',
#   'coryneform bacterium ATCC11425',
#   ['Bacillus pyelonephritidis boum',
#    'Bacillus pyelonephritidis bovis',
#    'Bacillus pyelonephritidis',
#    'Bacillus pyelonephritis bovis',
#    'Bacillus renalis',
#    'Bacterium renale',
#    'Corynebacterium ovale',
#    'Mycobacterium renale'],
#   ['Bacillus xerosis',
#    'Bacterium colomatti',
#    'Bacterium xerosis',
#    'Corynebacterium conjunctivae',
#    'Mycobacterium xerosis',
#    'Pacinia neisseri'],
#   ['Arthrobacter variabilis',
#    'Caseobacter polymorphus',
#    'Corynebacterium mooreparkense',
#    'Corynebacterium variabilis'],
#   'unclassified coryneform bacteria',
#   'Eubacterium acidaminophilum',
#   'Eubacterium oxidoreducans',
#   'Eubacteria environmental samples',
#   ['Bacteroides biformis', 'Eubacterium biforme', 'Pseudobacterium biforme'],
#   ['Bacteroides limosus',
#    'Butyribacterium limosum',
#    'Butyribacterium rettgeri',
#    'Mycobacterium limosum'],
#   ['Bacillus spatuliformis',
#    'Bacillus tenuis spatuliformis',
#    'Bacteroides tenuis',
#    'Cillobacterium spatuliforme',
#    'Cillobacterium tenue',
#    'Eubacterium tenue'],
#   'Propionibacterium group',
#   ['Bacterium acidi propionici a',
#    'Bacterium acidi propionici d',
#    'Propionicibacterium freudenreichii'],
#   ['Bacillus acnes', 'Corynebacterium acnes', 'Propionibacterium acnes'],
#   ['Bacillus acidi propionici',
#    'Propionibacterium acidi-propionici',
#    'Propionibacterium acidipropionici',
#    'Propionibacterium arabinosum',
#    'Propionibacterium pentosaceum'],
#   ['Bacterium acidi propionici b',
#    'Propionibacterium jensenii',
#    'Propionibacterium jensenii var. raffinosaceum',
#    'Propionibacterium peterssonii',
#    'Propionibacterium raffinosaceum',
#    'Propionibacterium technicum',
#    'Propionibacterium zeae'],
#   ['Actinomyces propionicus',
#    'Propionibacterium propionicus',
#    'Pseudopropionibacterium propionicum'],
#   'Pseudopropionibacterium',
#   ['Bacterium acidi propionici var. rubrum',
#    'Propionibacterium rubrum',
#    'Propionibacterium thoenii'],
#   ['Propionibacterium freudenreichii shermanii',
#    'Propionibacterium shermanii'],
#   ['Propionibacterium innocuum', 'Propioniciferax innocuum'],
#   ['Actinobacteria', 'Actinomycetes', 'High GC gram-positive bacteria'],
#   ['Actinobacteraeota', 'Actinobacteriota'],
#   ['Bacillus tuberculosis gallinarum',
#    'Mycobacterium tuberculosis avium',
#    'Mycobacterium tuberculosis typus gallinaceus',
#    'Tuberculose des oiseaux'],
#   ['Mycobacterium tuberculosis typus bovinus',
#    'Mycobacterium tuberculosis var. bovis'],
#   ['Bacillus tuberculosis',
#    'Bacterium tuberculosis',
#    'Mycobacterium tuberculosis typus humanus',
#    'Mycobacterium tuberculosis var. hominis',
#    'Mycobacterium tuberculosis variant tuberculosis'],
#   ['Mycobacterium fortuitum', 'Mycobacterium giae', 'Mycobacterium minetti'],
#   'Mycobacterium fortuitum complex',
#   'Nocardia intracellularis',
#   'Bacillus leprae',
#   ['Bacillus paratuberculosis',
#    'Bacterium paratuberculosis',
#    'Darmtuberculose',
#    'Mycobacterium enteritidis',
#    'Mycobacterium johnei',
#    'Mycobacterium paratuberculosis'],
#   ['Bacterium phlei', 'Mycobacterium phlei', 'Sclerothrix phlei'],
#   ['Bacillus smegmatis',
#    'Bacterium smegmatis',
#    'Mycobacterium paratuberculosis smegmatis',
#    'Mycobacterium smegmatis'],
#   ['Mycobacterium chelonae', 'Mycobacterium chelonei'],
#   'Mycobacterium chelonae complex',
#   'Mycobacterium flavescens',
#   'Mycobacterium komossense',
#   ['Mycobacterium balnei', 'Mycobacterium platypoecilus'],
#   'Mycobacterium nonchromogenicum',
#   'Mycobacterium terrae complex',
#   'Mycobacterium habana',
#   'Mycobacterium sphagni',
#   'Mycobacterium terrae',
#   ['Mycobacterium xenopei',
#    'Mycobacterium xenopi Schwabacher 1959 (Approved Lists) emend. Nouioui et al. 2018'],
#   'Mycobacterium aurum',
#   'Mycobacterium chitae',
#   'Mycobacterium fallax',
#   'Mycobacterium gadium',
#   'Mycobacterium neoaurum',
#   ['Mycobacterium farcinogenes subsp. senegalense',
#    'Mycobacterium senegalense'],
#   'Mycobacterium thermoresistibile',
#   'Mycobacterium triviale',
#   'Mycobacterium triviale complex',
#   'Mycobacterium aichiense',
#   'Mycobacterium chubuense',
#   'Mycobacterium diernhoferi',
#   ['Mycobacterium farcinigenes',
#    'Mycobacterium farcinogenes subsp. farcinogenes',
#    'Mycobacterium farcinogenes subsp. tchadense',
#    'Mycobacterium farcinogenes'],
#   'Mycobacterium gilvum',
#   ['Mycobacterium muris', 'Mycobacterium tuberculosis var. muris'],
#   'Mycobacterium obuense',
#   'Mycobacterium vaccae',
#   "'Mycobacterium hyorhinis'",
#   'Yuhushiella',
#   'Actinosynnemataceae',
#   ['Amycolatopsis fastidiosa', 'Pseudonocardia fastidiosa'],
#   'Micropolyspora',
#   'Williamsiaceae',
#   ['Mycobacterium globerulum',
#    'Nocardia globea',
#    'Nocardia globosa',
#    '"Proactinomyces globerulus" (Gray 1928) Reed 1939'],
#   ['Actinomyces caviae', 'Nocardia caviae', 'Nocardia otitidis-caviarum'],
#   ['Actinomyces asteroides',
#    'Actinomyces eppingeri',
#    'Actinomyces eppinger',
#    'Asteroides asteroides',
#    'Cladothrix asteroides',
#    'Discomyces asteroides',
#    'Oospora asteroides',
#    'Proactinomyces asteroides',
#    'Streptothrix eppingerii',
#    'Streptotrix asteroides'],
#   ['Bacterium fascians',
#    'Corynebacterium fascians',
#    '"Mycobacterium luteum" Sohngen 1913',
#    'Phytomonas fascians',
#    'Pseudobacterium fasciens',
#    'Rhodococcus luteus'],
#   ['Bacterium mycoides roseum',
#    'Gordona rosea',
#    'Rhodococcus roseus',
#    'Staphylococcus rhodochrous'],
#   ['Gordona lentifragmenta',
#    'Nocardia rubra',
#    'Proactinomyces rubra',
#    'Rhodococcus lentifragmentus',
#    'Streptothrix rubra'],
#   ['Arthrobacter hydrocarboglutamicus',
#    'Arthrobacter oxamicetus subsp. propiophenicolus',
#    'Arthrobacter oxamicetus',
#    'Arthrobacter paraffineus',
#    'Arthrobacter picolinophilus',
#    'Brevibacterium healii',
#    'Brevibacterium ketoglutamicum',
#    'Brevibacterium paraffinoliticum',
#    'Corynebacterium alkanum',
#    'Corynebacterium aurantiacum',
#    'Corynebacterium humiferum',
#    'Mycobacterium erythropolis',
#    'Nocardia calcarea'],
#   ['Actinomyces erythreus',
#    'Streptomyces erythraeus',
#    '"Streptomyces erythreus" (sic) (Waksman 1923), Waksman and Henrici 1948'],
#   'Nocardioides group',
#   'Pimelobacter jensenii',
#   'Mzabimycetaceae Saker et al. 2015',
#   ['Micropolyspora internatus',
#    'Saccharomonospora internatus',
#    'Thermoactinomyces viridis'],
#   'Frankiella',
#   ['Frankia FaC1', 'Frankia sp. (strain FaC1)'],
#   ['Frankia Arl3', 'Frankia sp. (strain ArI3)', 'Frankia sp. (strain Arl3)'],
#   ['Actinomyces alni',
#    'Aktinomyces alni',
#    'Frankia subtilis',
#    'Frankiella alni',
#    'Nocardia alni',
#    'Plasmodiophora alni',
#    'Proactinomyces alni',
#    'Schinzia alni',
#    '"Streptomyces alni" (Woronin 1866) Fiuczek 1959'],
#   'Dermatophylus',
#   ['Actinomyces congolensis',
#    'Atinomyces dermatonomus',
#    'Dermatophilus dermatonomus',
#    'Dermatophilus pedis',
#    'Dermatophylus congolense',
#    'Nocardia dermatonomus',
#    '"Streptothrix bovis" Snijders and Jansen 1955',
#    'Tetragenus congolensis'],
#   'Amorphosporangium',
#   'Actinocatenisporaceae Salam et al. 2020',
#   ['Actinoplanes digitatus', 'Ampullaria digitata', 'Ampullariella digitata'],
#   'Ampullariella sp.',
#   ['Actinoplanes ATCC31351',
#    'Ampullariella ATCC31351',
#    'Ampullariella sp. (ATCC 31351)',
#    'Ampullariella sp. (strain 3876)'],
#   'Jishengella',
#   ['Micromonospora chalcease', 'Nocardia chalcea', 'Strepthotrix chalcea'],
#   ['Micromonospora purpurea', 'Micromonospora rhodorangea'],
#   "'Micromonospora rosea'",
#   ...]}

# %%
all_values_of_each_attribute['scientific_name'][300000]
# Out:
# 'Thiomonas sp. ML1-15'

# %%
def create_one_values_to_node_id_dict(temp_nx,temp_node,relevant_node_set):
    '''
    This takes a single node and returns a dict
    where the keys (probably many) are the nested values of the node
    and the value for each key is the node ID
    '''
    one_node_id_dict=dict()
    #we make scientific name the endpoint so that it works like the mesh hierarchies
    #scientific_name=temp_nx.nodes[temp_node][temp_attribute]
    for temp_attribute in relevant_node_set:
        #print(temp_attribute)
        if temp_attribute not in temp_nx.nodes[temp_node].keys():
            continue
        elif isinstance(temp_nx.nodes[temp_node][temp_attribute],str):
            #print(total_ncbi_networkx.nodes[temp_node][temp_attribute])
            one_node_id_dict[temp_nx.nodes[temp_node][temp_attribute]]=temp_node
        else:
            #print(set(flatten(total_ncbi_networkx.nodes[temp_node][temp_attribute])))
            temp_dict={
                element:temp_node for element in set(flatten(temp_nx.nodes[temp_node][temp_attribute]))
            }
            one_node_id_dict.update(temp_dict)
    return one_node_id_dict

# %%
create_one_values_to_node_id_dict(total_ncbi_networkx,'9606',set_that_encapulates_node_id)
# Out:
# {'man': '9606', 'Homo sapiens': '9606', 'human': '9606'}

# %%
total_ncbi_networkx.nodes['566']
# Out:
# {'rank': 'species',
#  'synonym': ['Alma group 1',
#   'API group 2',
#   'CDC Enteric Group 1',
#   'Enterobacter vulneris',
#   'Escherichia vulneris'],
#  'type_material': ['ATCC 33821',
#   'CCUG 15715',
#   'CDC 875-72',
#   'CIP 103177',
#   'DSM 4564',
#   'HAMBI 1694',
#   'JCM 1688',
#   'LMG 7868',
#   'LMG:7868',
#   'NBRC 102420',
#   'NCTC 12130'],
#  'equivalent_name': 'Escherichia/Shigella vulneris',
#  'authority': ['Escherichia vulneris Brenner et al. 1983',
#   'Pseudescherichia vulneris (Brenner et al. 1983) Alnajar and Gupta 2017'],
#  'scientific_name': 'Pseudescherichia vulneris'}

# %%
def create_all_attribute_to_node_id_dict(temp_nx,relevant_node_set):
    '''
    takes an entire networkx and features that help to differentiate nodes
    returns a dict of {attribute:node_id}
    '''
    total_feature_node_id_dict=dict()
    for i,temp_node in enumerate(temp_nx.nodes):
        #if i%100!=0:
        #    continue
        total_feature_node_id_dict.update(
            create_one_values_to_node_id_dict(temp_nx,temp_node,relevant_node_set)
        )
    #    if i >100:
    #        break
    #print(total_feature_node_id_dict)
    return total_feature_node_id_dict

# %%
my_dict=create_all_attribute_to_node_id_dict(total_ncbi_networkx,set_that_encapulates_node_id)

# %%
with open('small_ncbi_names.json', 'w') as fp:
    json.dump(my_dict, fp,indent=4)

# %%
#print(my_dict.keys())
